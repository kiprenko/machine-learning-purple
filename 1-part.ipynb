# %% [markdown]
# ## Машинное обучение. Работа с данными и построение регрессионных моделей
# ##### Подготовил Кипренко Евгений
# email: zhenyakiprenko@gmail.com
#
# Загружаем наш изначальный (полный) ДатаФрейм, чтобы выделить из него тестовый Датафрейм.<br><br>
# **Важно:** в первой части лабораторной работы я использовал тестовый датасет лишь для тестирования написанного кода. Но анализ графиков и выполнение пукнтов первой части ЛР были  сделаны на оригинальном полном датасете.<br><br>
# Я решил, что мой тестовый Датафрейм, в контексте данной задачи, будет 5%, что равно 0.05.Аргументирую это тем, что полный датасет в 5000+ данных очень долго будет обрабатываться. А 5%, что равно примерно 250 записям - нет.\
# Насколько я понял, в предоставленном датасете первый столбец это просто номера строк. Потому я указал параметр `index_col=0` при считывании csv файла, чтобы номера строк брались из этого первого столбца.

# %%
import pandas as pd
import json

df = pd.read_csv('cinema1.csv', index_col=0)

# %% [markdown]
# **ЕСЛИ ВЫ ХОТИТЕ ИСПОЛЬЗОВАТЬ ТЕСТОВЫЙ (УМЕНЬШЕНЫЙ) ДАТАСЕТ, РАСКОММЕНТИРУЙТЕ ЭТИ ДВЕ СЛЕДУЮЩИЕ СТРОКИ**

# %%
# test_dataset_size = int(0.05 * len(df))
# df = df.iloc[0:test_dataset_size]

# %%
print('Размер обрабатываемого датафрейма:', len(df))
# Out:
# Размер обрабатываемого датафрейма: 5046

# %% [markdown]
# Далее, удалим из нашего ДатаФрейма столбцы, которые не заполнены хотя бы на половину данными. Функция `missing_values_table` не моя, спёр её с одной статьи на Хабре, я лишь немножечко подправил её для условий своей задачи. Украл, кажись, [отсюда](https://habr.com/ru/company/nix/blog/425253/).

# %%
# Function to calculate missing values by column
def missing_values_table(df):
        # Total missing values
        mis_val = df.isnull().sum()
        
        # Percentage of missing values
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        
        # Make a table with the results
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        
        # Rename the columns
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        
        # Sort the table by percentage of missing descending
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        
        # Print some summary information
        print ("В датафрейме " + str(df.shape[1]) + " столбцов.\n"    
            "Имеются " + str(mis_val_table_ren_columns.shape[0]) +
              " столбцов, в которых есть отсутствующие значения.")
        
        # Return the dataframe with missing information
        return mis_val_table_ren_columns

missing_df = missing_values_table(df);
missing_columns = list(missing_df[missing_df['% of Total Values'] > 50].index)
print('Будет удалено %d столбцов.' % len(missing_columns), 'среди которых такие: ', missing_columns)

# Drop the columns
data = df.drop(columns = missing_columns)
# Out:
# В датафрейме 31 столбцов.
# Имеются 0 столбцов, в которых есть отсутствующие значения.
# Будет удалено 0 столбцов. среди которых такие:  []

# %% [markdown]
# Заменяем NaN на -1.
# Выбрал -1 потому, что это частая практика в программировании заменять отсутствие значения таким числом. Плюс, насколько я заметил, в наших данных все числа больше 0, а это значит, что я не внесу своими минус единицами проблем.

# %%
df = df.replace("-1", -1)
df = df.fillna(-1)

# %% [markdown]
# Сохраним наш тестовый Датафрейм.

# %%
df.to_csv(path_or_buf='test_cinema1.csv')

# %% [markdown]
# Для удобства, выведу сюда столбцы нашего датафрейма. Заюзаем json чтобы вывести красивенько. Сделаем функцию для красивой печати списков, словарей и т. д.

# %%
def prettify(iterable):
    return json.dumps(iterable, indent=4)

# %%
print('Наш Датафрейм имеет такие столбцы:\n', prettify(list(df.columns.values)))
# Out:
# Наш Датафрейм имеет такие столбцы:
#  [
#     "color",
#     "director_name",
#     "num_critic_for_reviews",
#     "duration",
#     "director_facebook_likes",
#     "actor_3_facebook_likes",
#     "actor_2_name",
#     "actor_1_facebook_likes",
#     "gross",
#     "genres",
#     "actor_1_name",
#     "movie_title",
#     "num_voted_users",
#     "cast_total_facebook_likes",
#     "actor_3_name",
#     "facenumber_in_poster",
#     "plot_keywords",
#     "movie_imdb_link",
#     "num_user_for_reviews",
#     "language",
#     "country",
#     "content_rating",
#     "budget",
#     "title_year",
#     "actor_2_facebook_likes",
#     "imdb_score",
#     "aspect_ratio",
#     "movie_facebook_likes",
#     "Unnamed: 28",
#     "war_symb_title",
#     "point_symb_title"
# ]

# %% [markdown]
# ### Построим распределение жанров по рейтингу, прибыльности, лайкам
#
# Вытащим жанры, лайки, прибыль и рейтинг фильмов, чтобы построить наше распределение.
# **Надеюсь я не ошибся и правильно понял, что прибыль это 'gross'.**
# В качестве рейтинга используем Рейтинг IMDB

# %%
genres_likes_df = df[['genres', 'movie_facebook_likes', 'gross', 'imdb_score']]

# %% [markdown]
# Подсчитываем суммарно лайки, прибыль и рейтинг для каждого из жанров. Так как жанров у фильма несколько, то мы разделяем cnhjre c ними, чтобы получить конкретные жанры и считаем для каждого отдельно. Для разделения используем `row['genres'].split('|')`, ведь | это спецсимвол, что разделяет жанры в строке жанров у каждого фильма.
# К примеру, если у фильма жанр Fantasy и Adventure, а прибыль 100 000, значит что мы запишем прибиль для Fantasy 100 000 и Adventure 100 000.
# Для удобства используем Counter, он нам поможет потом легко отделить лишь самые топовые по показателям жанры.

# %%
from collections import Counter

# Добавляет значение в счётчик, если такого ключа там ещё нет.
# Иначе, добавит новое значение к уже имеющемуся
def add_or_sum_to_counter(c: Counter, key: str, value: float):
    if value == -1:
        return
    
    if key in c.keys():
        c[key] += value
    else:
        c[key] = value
    

genres_likes = Counter()
genres_gross = Counter()
genres_score = Counter()
# Считаем сколько фильмов каждого жанра, чтобы потом сделать нормализацию.
genres_films_count = Counter()
for index, row in genres_likes_df.iterrows():
    genres_list = row['genres'].split('|')
    for genre in genres_list:
        add_or_sum_to_counter(genres_likes, genre, float(row['movie_facebook_likes']))
        add_or_sum_to_counter(genres_gross, genre, float(row['gross']))
        add_or_sum_to_counter(genres_score, genre, float(row['imdb_score']))
        add_or_sum_to_counter(genres_films_count, genre, 1)

print('Топ-3 жанра суммарно по лайкам\n', prettify(genres_likes.most_common(3)))
print('Топ-3 жанра суммарно по прибыли\n', prettify(genres_gross.most_common(3)))
print('Топ-3 жанра суммарно по рейтингу\n', prettify(genres_score.most_common(3)))
# Out:
# Топ-3 жанра суммарно по лайкам
#  [
#     [
#         "Drama",
#         19963537.0
#     ],
#     [
#         "Adventure",
#         12201535.0
#     ],
#     [
#         "Action",
#         12021768.0
#     ]
# ]
# Топ-3 жанра суммарно по прибыли
#  [
#     [
#         "Adventure",
#         79806607293.0
#     ],
#     [
#         "Comedy",
#         77432370500.0
#     ],
#     [
#         "Action",
#         75145540469.0
#     ]
# ]
# Топ-3 жанра суммарно по рейтингу
#  [
#     [
#         "Drama",
#         17538.900000000023
#     ],
#     [
#         "Comedy",
#         11629.600000000006
#     ],
#     [
#         "Thriller",
#         8904.000000000007
#     ]
# ]

# %% [markdown]
# ##### Делаем нормализацию перед тем как строить распределение по жанрам.
# Сначала делим сумму лайков, прибыли и рейтинга для каждого из жанров чтобы найти среднее значение.

# %%
def take_avg(c: Counter, key: str, value: float):
    # It's easier to ask for forgiveness than getting permission
    try:
        c[key] = c[key] / value
    except KeyError:
        pass

for genre, films_count in genres_film_count.items():
    take_avg(genres_likes, genre, films_count)
    take_avg(genres_gross, genre, films_count)
    take_avg(genres_score, genre, films_count)
    

print('Топ-3 жанра в среднем по лайкам', genres_likes.most_common(3))
print('Топ-3 жанра в среднем по прибыли',genres_gross.most_common(3))
print('Топ-3 жанра в среднем по рейтингу',genres_score.most_common(3))
# Out:
# Топ-3 жанра в среднем по лайкам [('Biography', 3237953.0), ('Music', 926614.0), ('Horror', 520127.14285714284)]
# Топ-3 жанра в среднем по прибыли [('Biography', 9005655093.0), ('Music', 6454864344.0), ('Sport', 2317980574.6666665)]
# Топ-3 жанра в среднем по рейтингу [('Biography', 2095.0000000000005), ('Music', 1365.5), ('Documentary', 868.8000000000003)]

# %% [markdown]
# Теперь используя наши средние значения делаем нормализацию.
# К примеру, если брать лайки, делим лайки одного жанра на сумму лайков всех жанров. И так же для прибыли и рейтинга.

# %%
likes_sum = sum(genres_likes.values())
grosses_sum = sum(genres_gross.values())
scores_sum = sum(genres_score.values())

for genre in genres_films_count.keys():
    genres_likes[genre] = (genres_likes[genre] / likes_sum) * 100
    genres_gross[genre] = (genres_gross[genre] / grosses_sum) * 100 
    genres_score[genre] = (genres_score[genre] / scores_sum) * 100

# %% [markdown]
# После того, как наши данные были подготовлены, можем рисовать наши графики. Чтобы сделать графики более читаемыми, я решил выводить лишь топ-10. При надобности, вы можете вывести любое число.
#
# **Обратите внимание, что были посчитаны средние значения и проделана нормализация для значений на графиках**
#
# Применим fivethirtyeight, чтобы по красоте всё:)

# %%
import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')

top_genres_by_likes = dict(genres_likes.most_common(10))
plt.figure(figsize=(18, 9))
plt.bar(list(top_genres_by_likes.keys()), list(top_genres_by_likes.values()), color='cyan') 
plt.xlabel('Жанр') 
plt.ylabel('Средний процент лайков') 
plt.title('Топ жанров фильмов по лайкам', color='black')
plt.savefig('Топ жанров фильмов по лайкам.png')
plt.show() 

top_genres_by_gross = dict(genres_gross.most_common(10))
plt.figure(figsize=(18, 9))
plt.bar(list(top_genres_by_gross.keys()), list(top_genres_by_gross.values()), color='green')  
plt.xlabel('Жанр') 
plt.ylabel('Средний процент прибыли') 
plt.title('Топ жанров фильмов по прибыли', color='black')
plt.savefig('Топ жанров фильмов по прибыли.png')
plt.show() 

top_genres_by_score = dict(genres_score.most_common(10))
plt.figure(figsize=(18, 9))
plt.bar(list(top_genres_by_score.keys()), list(top_genres_by_score.values()), color='orange')  
plt.xlabel('Жанр') 
plt.ylabel('Средний процент рейтинга') 
plt.title('Топ жанров фильмов по рейтингу', color='black') 
plt.savefig('Топ жанров фильмов по рейтингу.png')
plt.show()

# %% [markdown]
# **Анализ графиков** биография в топе по всем рейтингам. Зная, что в датасете есть пасхалочки, будем держать эту информацию в уме и когда дойдёт очередь до поиска пасхалок - обязательно к ней вернёмся. <br>
# Так же видно, что фильмы, у которых жанр музыка или документалистика, довольно успешны.

# %% [markdown]
# ### Найти топ 20 связок (если такие есть) актер-режиссер, которые дают больше денег в прокате
#
# Составим пары режиссёр-актёр, а после будем считать для них статистику.
# Используем уже знакомый нам collections.Counter. Не забываем проверочку на -1.
# Если для предыдущих графиков я брал среднее, то в это раз не буду. Дело касается денег и нет смысла брать среднее.

# %%
def count_director_actor_gross(c: Counter(), director: str, actor: str, gross: float):
    if director != -1 and actor != -1 and gross != -1:
        director_actor_pair = director.strip() + ' and ' + actor.strip()
        if director_actor_pair in c:
            c[director_actor_pair] += gross
        else:
            c[director_actor_pair] = gross

director_actor_gross = Counter()
for index, row in df[['director_name', 'actor_1_name', 'actor_2_name', 'actor_3_name', 'gross']].iterrows():
    director = row['director_name']
    gross = row['gross']
    count_director_actor_gross(director_actor_gross, director, row['actor_1_name'], gross)
    count_director_actor_gross(director_actor_gross, director, row['actor_2_name'], gross)
    count_director_actor_gross(director_actor_gross, director, row['actor_3_name'], gross)

# %% [markdown]
# Получили наши данные в формате Режиссёр-Актёр: прибыль, которую они заработали.
# Теперь строим наш график и выводим Топ-20 (для чего нам и пригодится Counter).
# Подпись Режиссёр-Актёр сделал вертикально, чтобы не сливались надписи.

# %%
top_dir_act_by_gross = dict(director_actor_gross.most_common(20))
plt.figure(figsize=(18, 9))
heights = [10, 20, 15]
bars = list(top_dir_act_by_gross.keys())
y_pos = range(len(bars))
plt.bar(y_pos, list(top_dir_act_by_gross.values())) 
# Rotation of the bars names
plt.xticks(y_pos, bars, rotation=90, color='black')
plt.xlabel('Режисёр и актёр') 
plt.ylabel('Прибыль в у. е.') 
plt.title('Топ-20 пар режисёров и актёров по прибыли', color='black')
plt.savefig('Топ-20 пар режисёров и актёров по прибыли.png')
plt.show()

# %% [markdown]
# **Анализ графика** вот и ещё одна пасхалочка нашлась. В топе есть три актёра в паре с каким-то неизвестным поиску Google режиссёром. Не уж то пасхалочка. Но об этом потом. Пока что есть другие пункты в лабе :)<br>
# По графику сказать больше нечего, выглядит нормальным. Если не рассматривать те странные три пары, которые скорее всего пасхалка, видно, что есть троица из какого-то фильма про Мстителей: режиссёр Джосс Видон, актёры Крис Хэмсворт, Р. Дауни Младший и Скарелт Йохансен.

# %% [markdown]
# ### Указать, фильмы из какой страны имеют лучший средний рейтинг. Проанализировать ответ и аргументировать вердикт

# %%
country_sum_score = Counter()
counter_film_count = Counter()
for index, row in df[['country', 'imdb_score']].iterrows():
    country = row['country']
    score = row['imdb_score']
    if country == -1 or score == -1:
        continue
    add_or_sum_to_counter(country_sum_score, country, score)
    add_or_sum_to_counter(counter_film_count, country, 1)
print('Количество фильмов по странам \n', prettify(counter_film_count))
# Out:
# Количество фильмов по странам
#  {
#     "USA": 3807,
#     "UK": 448,
#     "New Zealand": 15,
#     "Canada": 131,
#     "Australia": 55,
#     "Belgium": 4,
#     "Japan": 23,
#     "Germany": 97,
#     "China": 30,
#     "France": 154,
#     "Mexico": 17,
#     "Spain": 33,
#     "Hong Kong": 17,
#     "Czech Republic": 3,
#     "India": 34,
#     "Soviet Union": 1,
#     "South Korea": 14,
#     "Peru": 1,
#     "Italy": 23,
#     "Russia": 11,
#     "Aruba": 1,
#     "Denmark": 11,
#     "Libya": 1,
#     "Ireland": 12,
#     "South Africa": 8,
#     "Iceland": 3,
#     "Switzerland": 3,
#     "Romania": 4,
#     "West Germany": 3,
#     "Chile": 1,
#     "Netherlands": 5,
#     "Hungary": 2,
#     "Panama": 1,
#     "Greece": 2,
#     "Sweden": 6,
#     "Norway": 8,
#     "Taiwan": 2,
#     "Cambodia": 1,
#     "Thailand": 5,
#     "Slovakia": 1,
#     "Bulgaria": 1,
#     "Iran": 4,
#     "Poland": 5,
#     "Georgia": 1,
#     "Turkey": 1,
#     "Nigeria": 1,
#     "Brazil": 8,
#     "Finland": 1,
#     "Bahamas": 1,
#     "Argentina": 4,
#     "Colombia": 1,
#     "Israel": 4,
#     "Egypt": 1,
#     "Kyrgyzstan": 1,
#     "Indonesia": 1,
#     "Pakistan": 1,
#     "Slovenia": 1,
#     "Afghanistan": 1,
#     "Dominican Republic": 1,
#     "Cameroon": 1,
#     "United Arab Emirates": 1,
#     "Kenya": 1,
#     "Philippines": 1
# }

# %% [markdown]
# Видно, что в этом списке не только страны, а и какие-то другие слова. Как например New Line. Запомнили, вернёмся, когда дойдёт очередь до поиска пасхалочек.

# %% [markdown]
# Находим среднюю прибыль.

# %%
for country, score in country_sum_score.items():
    country_sum_score[country] = score / counter_film_count[country]
print('Средний рейтинг фильмов по странам: \n', prettify(country_sum_score))
# Out:
# Средний рейтинг фильмов по странам:
#  {
#     "USA": 6.36782243236144,
#     "UK": 6.8183035714285705,
#     "New Zealand": 7.279999999999999,
#     "Canada": 6.193893129770993,
#     "Australia": 6.5145454545454555,
#     "Belgium": 5.6,
#     "Japan": 6.952173913043477,
#     "Germany": 6.340206185567008,
#     "China": 6.623333333333332,
#     "France": 6.678571428571429,
#     "Mexico": 6.776470588235294,
#     "Spain": 6.8242424242424224,
#     "Hong Kong": 6.741176470588235,
#     "Czech Republic": 6.966666666666666,
#     "India": 6.532352941176472,
#     "Soviet Union": 8.1,
#     "South Korea": 6.257142857142858,
#     "Peru": 5.4,
#     "Italy": 6.873913043478259,
#     "Russia": 6.081818181818182,
#     "Aruba": 4.8,
#     "Denmark": 7.172727272727272,
#     "Libya": 8.4,
#     "Ireland": 6.783333333333334,
#     "South Africa": 6.4375,
#     "Iceland": 7.333333333333333,
#     "Switzerland": 5.8999999999999995,
#     "Romania": 6.6,
#     "West Germany": 7.266666666666667,
#     "Chile": 6.9,
#     "Netherlands": 6.94,
#     "Hungary": 6.449999999999999,
#     "Panama": 7.2,
#     "Greece": 7.0,
#     "Sweden": 7.516666666666666,
#     "Norway": 6.7375,
#     "Taiwan": 7.15,
#     "Cambodia": 5.6,
#     "Thailand": 6.08,
#     "Slovakia": 6.0,
#     "Bulgaria": 6.1,
#     "Iran": 7.725,
#     "Poland": 7.62,
#     "Georgia": 5.6,
#     "Turkey": 6.0,
#     "Nigeria": 5.6,
#     "Brazil": 7.2749999999999995,
#     "Finland": 7.2,
#     "Bahamas": 4.4,
#     "Argentina": 7.5,
#     "Colombia": 7.5,
#     "Israel": 7.5249999999999995,
#     "Egypt": 8.1,
#     "Kyrgyzstan": 8.7,
#     "Indonesia": 7.6,
#     "Pakistan": 7.0,
#     "Slovenia": 6.4,
#     "Afghanistan": 7.4,
#     "Dominican Republic": 6.9,
#     "Cameroon": 7.5,
#     "United Arab Emirates": 8.2,
#     "Kenya": 7.4,
#     "Philippines": 6.3
# }

# %% [markdown]
# И здесь точно так же. Не у всех фильмов в графе страна указана действительно страна. Баг или фича, вот в чём вопрос)

# %% [markdown]
# А теперь строим наш график. Вывожу лишь Топ-10 для читаемости. При надобности, можете вывести больше или меньше

# %%
top_film_countries_by_rate = dict(country_sum_score.most_common(10))
plt.figure(figsize=(18, 9))
plt.bar(list(top_film_countries_by_rate.keys()), list(top_film_countries_by_rate.values()), color='green')  
plt.xlabel('Страна производитель фильма') 
plt.ylabel('Средний рейтинг') 
plt.title('Топ стран по среднему рейтингу фильмов', color='black')
plt.savefig('Топ стран по среднему рейтингу фильмов.png')
plt.show()

# %% [markdown]
# **Анализ графика**: мы видим, что в топ вырвались страны, у которых фильмов было меньше.
# А это значит, что при подсчёте среднего рейтинга это выбило их в топ.
# Ведь если взять США, у которой фильмо много, но они как плохие, так и хорошие, потому средний рейтинг ниже, чем устран, где фильмов мало.
# То есть, для более адекватного подсчёта среднего значения, лучше убрать из выборки страны, которые произвели фильмов меньше какого-то определённого значения. Скажем, чтобы фильмов у страны было не менее 10. <br>
# **Но самое важное**, что в топе по среднему рейтингу фильмы из страны English. Вроде как страна называется England, а не English. Но что удивительно, средний рейтинг аж 98. А этого быть не может, ведь максимальный средний рейтинг лишь 10. Значит мы видим некорректные данные. Или же пасхалочку.

# %% [markdown]
# ### Какой сюжет в среднем содержат фильмы жанра драма (plot_keywords). Есть ли у этих фильмов общий сюжетный ход

# %% [markdown]
# По условиям задания нам нужны лишь драматические фильмы. Значит вытащим из датафрейма лишь данные о фильмах жанра драма, чтобы упросить компьютеру жизнь при последующих манипуляциях.
# так как жанров у фильмов обычно больше чем один, а в нашем датасете жанры записаны в одну строку, применяем contains для поиска вхождения слова _Drama_ в строку жанров каждого из фильмов.

# %%
drama_films = df[df['genres'].str.contains('Drama')]

# %% [markdown]
# Я решил, что для поиска общего сюжета драматических фильмов, нужно посчитать вхождения слов в plot_keywords, а дальше вывести на график наиболее популярные слова в plot_keywords, а так же самое популярное, что и будет общим сюжетным ходом.
# Опять воспользуемся Counter(), очень он удобен для подсчёта всяких таких штук.

# %%
drama_films_plot_keywords_list = []
drama_films_count = len(drama_films)
for index, plot_keywords in drama_films['plot_keywords'].iteritems():
    if plot_keywords != -1:
        [drama_films_plot_keywords_list.append(keyword) for keyword in plot_keywords.split('|')]
drama_films_plot_keywords_counter = Counter(drama_films_plot_keywords_list)
print('Всего фильмов в жанре драма: ', drama_films_count)
print('Топ-10 самых используемых слов в сюжете фильмов жанра драма:')
for word in drama_films_plot_keywords_counter.most_common():
    print(word[0], " ", word[1])
# Out:
# Всего фильмов в жанре драма:  2593
# Топ-10 самых используемых слов в сюжете фильмов жанра драма:
# love   143
# friend   107
# murder   83
# death   76
# police   70
# friendship   56
# school   52
# new york city   51
# high school   46
# boy   45
# drugs   43
# marriage   41
# revenge   37
# lawyer   35
# money   35
# female protagonist   34
# fbi   33
# singer   33
# male nudity   32
# student   32
# hospital   31
# sex   31
# prison   30
# secret   30
# texas   30
# violence   28
# writer   28
# teacher   28
# dog   27
# girl   27
# female nudity   27
# vomiting   26
# best friend   26
# college   26
# based on true story   25
# party   24
# train   24
# doctor   24
# actor   24
# coach   24
# new york   24
# island   23
# detective   23
# hotel   23
# gay   23
# christmas   22
# president   21
# serial killer   21
# 1960s   21
# based on novel   21
# title directed by female   21
# neighbor   21
# battle   20
# fight   20
# cia   20
# 1970s   20
# journalist   20
# small town   20
# one word title   20
# 1950s   20
# cancer   20
# bar   20
# male frontal nudity   20
# teenager   20
# box office flop   19
# nudity   19
# african american   19
# family relationships   19
# basketball   19
# wedding   19
# escape   18
# faith   18
# soldier   18
# book   18
# professor   18
# bank   17
# letter   17
# gangster   17
# divorce   17
# suicide   17
# dance   17
# breasts   17
# 1980s   17
# baby   17
# pubic hair   17
# catholic   17
# army   16
# mexico   16
# apartment   16
# funeral   16
# sex scene   16
# gang   16
# memory   15
# boxing   15
# military   15
# alien   15
# children   15
# sheriff   15
# baseball   15
# car accident   15
# ghost   14
# king   14
# vampire   14
# india   14
# coming of age   14
# birthday   14
# dancer   14
# reporter   14
# american   14
# france   14
# racism   14
# football   14
# male rear nudity   14
# mafia   14
# female frontal nudity   14
# church   14
# restaurant   14
# jungle   13
# fire   13
# undercover   13
# 1930s   13
# terrorist   13
# beach   13
# nurse   13
# partner   13
# california   13
# desert   13
# flashback   13
# actress   13
# obsession   13
# criminal   13
# prostitute   13
# father son relationship   13
# stripper   13
# drug dealer   13
# china   13
# widow   13
# lesbian   13
# jewish   13
# robbery   13
# nazi   13
# summer   13
# england   12
# artist   12
# queen   12
# father daughter relationship   12
# blood   12
# captain   12
# male full frontal nudity   12
# photographer   12
# investigation   12
# rescue   12
# mother son relationship   12
# farm   12
# fbi agent   12
# infidelity   12
# spy   12
# musician   12
# neo noir   12
# bully   12
# male objectification   11
# martial arts   11
# superhero   11
# survival   11
# muslim   11
# scientist   11
# dream   11
# hostage   11
# russian   11
# prince   11
# gun   11
# corruption   11
# jew   11
# two word title   11
# colonel   11
# pilot   11
# christian   11
# salesman   11
# band   11
# trial   11
# heist   11
# 19th century   11
# alcoholic   11
# immigrant   11
# cult film   11
# priest   11
# dancing   11
# teenage girl   11
# independent film   11
# africa   10
# sequel   10
# general   10
# wealth   10
# slave   10
# husband wife relationship   10
# computer   10
# thief   10
# orphan   10
# radio   10
# betrayal   10
# sister   10
# cocaine   10
# song   10
# critically bashed   10
# depression   10
# ship   9
# robot   9
# future   9
# nonlinear timeline   9
# iraq   9
# rape   9
# magazine   9
# horse   9
# on the run   9
# graduation   9
# jealousy   9
# chef   9
# village   9
# art   9
# prisoner   9
# police detective   9
# 1990s   9
# assassin   9
# pastor   9
# dying   9
# gambling   9
# homosexual   9
# irish   9
# post apocalypse   8
# japan   8
# sea   8
# french   8
# heroin   8
# vietnam   8
# civil war   8
# epic   8
# boxer   8
# psychiatrist   8
# supernatural power   8
# suicide attempt   8
# mission   8
# audition   8
# television   8
# amnesia   8
# woods   8
# swimming pool   8
# chinese   8
# politics   8
# election   8
# widower   8
# kidnapping   8
# blood splatter   8
# training   8
# travel   8
# multiple perspectives   8
# psychologist   8
# suburb   8
# paranoia   8
# experiment   8
# male pubic hair   8
# pregnancy   8
# hip hop   8
# written and directed by cast member   8
# mother daughter relationship   8
# daughter   8
# car   8
# three word title   8
# road trip   8
# twin   8
# christian film   8
# river   8
# psychopath   7
# magic   7
# water   7
# storm   7
# box office hit   7
# female rear nudity   7
# fellatio   7
# whale   7
# brother sister relationship   7
# german   7
# princess   7
# hawaii   7
# airport   7
# vigilante   7
# mountain   7
# die hard scenario   7
# torture   7
# organized crime   7
# sergeant   7
# world war two   7
# bare breasts   7
# university   7
# character name in title   7
# politician   7
# patient   7
# italy   7
# maid   7
# competition   7
# redemption   7
# casino   7
# mental institution   7
# dysfunctional family   7
# adultery   7
# interview   7
# dea   7
# cowboy   7
# brother brother relationship   7
# soccer   7
# genius   7
# overalls   7
# time travel   7
# sister sister relationship   7
# drinking   7
# vacation   7
# drink   7
# painter   7
# poet   7
# nightmare   7
# coma   7
# cigarette smoking   7
# tragedy   6
# fairy tale   6
# virus   6
# werewolf   6
# honor   6
# conspiracy   6
# australia   6
# japanese   6
# navy   6
# afterlife   6
# religion   6
# police officer   6
# watching television   6
# snow   6
# dating   6
# heart attack   6
# italian   6
# mistress   6
# drifter   6
# hope   6
# concert   6
# russia   6
# bomb   6
# rivalry   6
# senator   6
# mobster   6
# newspaper   6
# bus   6
# virgin   6
# teenage boy   6
# boat   6
# scandal   6
# gold   6
# outlaw   6
# rancher   6
# lapd   6
# title spoken by character   6
# jail   6
# writing   6
# piano   6
# law   6
# psychic   6
# alaska   6
# homosexuality   6
# house   6
# domestic violence   6
# fear   6
# abuse   6
# mexican   6
# diner   6
# accident   6
# ranch   6
# retirement   6
# veteran   6
# prejudice   6
# guitar   6
# nun   6
# lust   6
# railroad   6
# boarding school   6
# manhattan new york city   6
# office   6
# number in title   6
# mormon   6
# hustler   6
# motel   6
# shower   6
# mansion   5
# anger   5
# remake   5
# tiger   5
# tournament   5
# lingerie slip   5
# ocean   5
# emperor   5
# pharaoh   5
# journey   5
# falling in love   5
# love triangle   5
# long take   5
# british   5
# 1920s   5
# ring   5
# smuggling   5
# heaven   5
# artificial intelligence   5
# assassination   5
# congressman   5
# surveillance   5
# affair   5
# colombia   5
# wilderness   5
# cuba   5
# new jersey   5
# farmer   5
# mental illness   5
# urination   5
# afghanistan   5
# protective male   5
# arab   5
# housekeeper   5
# planet   5
# stranded   5
# comic book   5
# circus   5
# world war one   5
# submarine   5
# panties   5
# subway   5
# agent   5
# invasion   5
# seduction   5
# governor   5
# chase   5
# fighting   5
# florida   5
# unfaithfulness   5
# los angeles california   5
# bodyguard   5
# marine   5
# activist   5
# vietnam war   5
# flight   5
# angel   5
# 2000s   5
# vengeance   5
# bridge   5
# hunter   5
# opera   5
# court   5
# boyfriend girlfriend relationship   5
# louisiana   5
# attorney   5
# justice   5
# freedom   5
# singing   5
# revolution   5
# voyeur   5
# oil   5
# courtroom   5
# six word title   5
# thailand   5
# four word title   5
# near death experience   5
# medical student   5
# jazz   5
# deputy   5
# servant   5
# girl in panties   5
# minister   5
# protest   5
# 1940s   5
# kiss   5
# mississippi   5
# oregon   5
# tourist   5
# reunion   5
# masturbation   5
# abusive husband   5
# drug cartel   5
# civil rights   5
# loss of father   5
# gay relationship   5
# food   5
# inheritance   5
# ambassador   5
# punctuation in title   5
# female full frontal nudity   5
# insanity   5
# painting   5
# novelist   5
# tragic event   5
# key   5
# boss   5
# orphanage   5
# adoption   5
# manager   5
# internet   5
# madea series   5
# based on play   5
# private school   5
# motorcycle   5
# unrequited love   5
# cunnilingus   5
# indian   5
# lesbian sex   5
# night   5
# brazil   5
# nightclub   5
# mother   5
# prayer   5
# poverty   5
# black comedy   5
# tradition   5
# slum   5
# tv mini series   5
# oral sex   5
# public nudity   5
# christmas eve   4
# wolf   4
# samurai   4
# monster   4
# older man younger woman relationship   4
# passenger   4
# greek   4
# cat   4
# secret service   4
# egypt   4
# 1800s   4
# hero   4
# african american protagonist   4
# astronaut   4
# combat   4
# witness   4
# historically inaccurate   4
# slavery   4
# imagination   4
# diamond   4
# emaciation   4
# sexual abuse   4
# alzheimer's disease   4
# research   4
# mole   4
# computer hacker   4
# sniper   4
# explosion   4
# game   4
# massacre   4
# secretary   4
# stranger   4
# bear   4
# billionaire   4
# tunnel   4
# flight attendant   4
# supernatural   4
# plot twist   4
# death of wife   4
# government   4
# plane crash   4
# con artist   4
# surprise ending   4
# football team   4
# 18th century   4
# sword   4
# bounty hunter   4
# cover up   4
# team   4
# nelson mandela   4
# aging   4
# north carolina   4
# corpse   4
# reality   4
# place name in title   4
# intern   4
# search   4
# spain   4
# district attorney   4
# eccentric   4
# wrestler   4
# career   4
# epidemic   4
# kicked in the crotch   4
# hitchcockian   4
# expedition   4
# u.s. civil war   4
# swimming   4
# blackmail   4
# inspired by true events   4
# judge   4
# working class   4
# hallucination   4
# marijuana   4
# scam   4
# sociopath   4
# shooting   4
# gay slur   4
# janitor   4
# magician   4
# tribe   4
# lake   4
# on the road   4
# trip   4
# alcoholism   4
# terminal illness   4
# u.s. army   4
# mayor   4
# cake   4
# car crash   4
# one night stand   4
# hong kong   4
# cartoon on tv   4
# written by director   4
# exorcism   4
# fashion   4
# english   4
# football coach   4
# author   4
# cheating wife   4
# union   4
# whipping   4
# strip club   4
# wine   4
# identity   4
# countess   4
# corrupt cop   4
# family reunion   4
# job   4
# female pubic hair   4
# horseback riding   4
# outcast   4
# prom   4
# fame   4
# biker   4
# preacher   4
# south africa   4
# fraud   4
# olympics   4
# loyalty   4
# intelligence   4
# single mother   4
# shakespeare play   4
# gay interest   4
# allies   4
# employer employee relationship   4
# rural setting   4
# bathtub   4
# 16th century   4
# waitress   4
# extramarital affair   4
# australian   4
# pakistan   4
# resurrection   4
# oxford   4
# neighborhood   4
# therapist   4
# speech   4
# camp   4
# satire   4
# london england   4
# mental breakdown   4
# movie star   4
# rock 'n' roll   4
# directed by star   4
# bartender   4
# surfer   4
# security guard   4
# ballet   4
# teen movie   4
# tied to a chair   4
# madness   4
# cult   4
# color in title   4
# street   4
# missionary   4
# first part   4
# immigration   4
# stereotype   4
# tears   4
# debate   4
# supermarket   4
# businessman   4
# dentist   4
# virginity   4
# therapy   4
# penis   4
# christianity   4
# pimp   4
# theft   4
# photography   4
# sexuality   4
# town   4
# child   4
# abortion   4
# underwear   4
# racist   4
# inmate   4
# bare chested male   4
# private detective   4
# animal name in title   3
# ape abducts a woman   3
# gorilla   3
# king kong   3
# titanic   3
# title appears in writing   3
# capture   3
# dam   3
# leader   3
# godzilla   3
# tough girl   3
# plague   3
# vision   3
# native american   3
# flood   3
# cattle   3
# fishing   3
# animal   3
# jerusalem   3
# knight   3
# roman empire   3
# elephant   3
# fisherman   3
# stockbroker   3
# composer   3
# nursing home   3
# nanny   3
# duke   3
# pedophile   3
# consciousness   3
# technology   3
# dictator   3
# haunted house   3
# undercover cop   3
# punk   3
# nazis   3
# android   3
# courage   3
# manipulation   3
# nsa   3
# terrorism   3
# surgery   3
# earth   3
# critically acclaimed   3
# crash   3
# usa   3
# pig   3
# mathematician   3
# uncle   3
# chaos   3
# fish out of water   3
# bank manager   3
# survivor   3
# disease   3
# latex gloves   3
# scotland   3
# communist   3
# vietnamese   3
# austria   3
# lieutenant   3
# loan shark   3
# philosophy   3
# maine   3
# rebellion   3
# bookstore   3
# prisoner of war   3
# trapped   3
# pianist   3
# con man   3
# strong female character   3
# ransom   3
# lobbyist   3
# dog movie   3
# prison guard   3
# disappearance   3
# driver   3
# death of husband   3
# panic   3
# law firm   3
# lawsuit   3
# journalism   3
# good versus evil   3
# apartheid   3
# execution   3
# golf   3
# golfer   3
# video store   3
# border   3
# alabama   3
# mutiny   3
# promotion   3
# alternate history   3
# bride   3
# missing child   3
# man with glasses   3
# fan   3
# iowa   3
# stage   3
# heart   3
# kentucky   3
# true crime   3
# ohio   3
# spirit   3
# navy seal   3
# break up   3
# kitchen   3
# client   3
# unlikely friendship   3
# number   3
# dystopia   3
# lebanon   3
# mercenary   3
# baseball movie   3
# tsunami   3
# twin brother   3
# panama   3
# heart transplant   3
# shark   3
# death row   3
# prostitution   3
# drug smuggling   3
# stagecoach   3
# u.s. marshal   3
# hindu   3
# butler   3
# prime minister   3
# cook   3
# southern california   3
# anti war   3
# work   3
# nevada   3
# courtship   3
# f word   3
# assistant   3
# frankenstein   3
# advertising   3
# karate   3
# mistaken identity   3
# high school student   3
# cold war   3
# sailor   3
# nature   3
# rock band   3
# san francisco california   3
# dragon   3
# blindness   3
# commitment   3
# binoculars   3
# crime boss   3
# woman wearing only a man's shirt   3
# male bonding   3
# texas ranger   3
# abusive father   3
# dolphin   3
# genetics   3
# forgiveness   3
# american football   3
# call girl   3
# corporation   3
# little league   3
# ghetto   3
# kansas   3
# illegal immigrant   3
# presumed dead   3
# kenya   3
# snake   3
# resistance   3
# vice president   3
# 3 dimensional   3
# telekinesis   3
# paramedic   3
# play   3
# theatre   3
# first person narration   3
# trauma   3
# twins   3
# business trip   3
# highway travel   3
# road movie   3
# hairy chest   3
# loss of virginity   3
# chick flick   3
# arranged marriage   3
# male in shower   3
# rage   3
# mortgage   3
# female warrior   3
# friendship between men   3
# breaking the fourth wall   3
# argument   3
# childhood friend   3
# debt   3
# gambler   3
# thug   3
# rabbi   3
# morgue   3
# home   3
# heiress   3
# bachelor   3
# desire   3
# bare chested male bondage   3
# leukemia   3
# age difference   3
# playwright   3
# single father   3
# duchess   3
# hollywood   3
# american dream   3
# anti semitism   3
# gang rape   3
# bible   3
# drug lord   3
# community   3
# housewife   3
# novel   3
# winter   3
# basketball player   3
# gay friend   3
# mixed martial arts   3
# shootout   3
# utah   3
# single set production   3
# rear entry sex   3
# emotional abuse   3
# mental hospital   3
# reference to god   3
# loneliness   3
# crucifixion   3
# sperm donor   3
# housing project   3
# adulterous wife   3
# unhappy marriage   3
# new mexico   3
# forename as title   3
# drummer   3
# interracial relationship   3
# childhood   3
# destiny   3
# borderline personality disorder   3
# aborigine   3
# hanging   3
# high school graduation   3
# grief   3
# thanksgiving   3
# no opening credits   3
# surfing   3
# director   3
# warehouse   3
# topless female nudity   3
# minnesota   3
# single   3
# suspect   3
# bible quote   3
# riot   3
# tension   3
# blaxploitation   3
# september 11 2001   3
# based on autobiography   3
# wager   3
# police officer killed   3
# colonialism   3
# iranian   3
# male female friendship   3
# reputation   3
# false accusation   3
# country music   3
# south central los angeles   3
# loss of mother   3
# zombie apocalypse   3
# business   3
# loss of loved one   3
# pregnant   3
# white panties   3
# cemetery   3
# germany   3
# subjective camera   3
# apostrophe in title   3
# fraternity   3
# poetry   3
# imperative in title   3
# latino   3
# escort   3
# bathroom   3
# miner   3
# sales   3
# bisexual   3
# convent   3
# narcissism   3
# lesbian kiss   3
# mexico city   3
# radiation   3
# stalking   3
# pennsylvania   3
# michigan   3
# voyeurism   3
# crime family   3
# canada   3
# political thriller   3
# lesbianism   3
# zombie   3
# based on short story   3
# iran   3
# steel worker   3
# male stripper   3
# killer   3
# class   3
# lesbian relationship   3
# burglary   3
# choir   3
# athlete   3
# cheerleader   3
# orgasm   3
# sexual promiscuity   3
# addiction   3
# bird   3
# claim in title   3
# native american protagonist   3
# bail   3
# unsimulated sex   3
# robin hood   2
# ingratitude   2
# scrooge   2
# tarzan   2
# based on comic book   2
# dc comics   2
# urban setting   2
# railway station   2
# ape   2
# space travel   2
# wormhole   2
# diary   2
# air raid   2
# bully comeuppance   2
# destruction   2
# pandemic   2
# asylum   2
# tour   2
# white house   2
# exodus   2
# moses   2
# pursuit   2
# super strength   2
# cult tv   2
# class differences   2
# revelation   2
# code   2
# duty   2
# u.s. soldier   2
# based on fairy tale   2
# second part   2
# space   2
# space station   2
# disaster movie   2
# earthquake   2
# arena   2
# boxing movie   2
# middle earth   2
# quest   2
# gym   2
# medieval times   2
# nasa   2
# battlefield   2
# gladiator   2
# assassination attempt   2
# corporate crime   2
# ku klux klan   2
# cathedral   2
# creature   2
# rebel   2
# starvation   2
# butcher   2
# somalia   2
# warlord   2
# dress   2
# fairy godmother   2
# pumpkin   2
# texan   2
# vermont   2
# life magazine   2
# hacker   2
# fairy   2
# message from outer space   2
# dual role   2
# northern ireland   2
# great depression   2
# horse racing   2
# limp   2
# disaster   2
# cannibalism   2
# bare chested boy   2
# stand up comedian   2
# kingdom   2
# architect   2
# fugitive   2
# weekend   2
# tv news   2
# partnership   2
# well   2
# giant robot   2
# tank   2
# hell   2
# crisis   2
# child abuse   2
# cryptography   2
# based on book   2
# arms dealer   2
# trio   2
# israel   2
# hostage negotiator   2
# train crash   2
# spaceship   2
# sphere   2
# comedian   2
# al qaeda   2
# legend   2
# revolt   2
# gulf war   2
# death of protagonist   2
# killing an animal   2
# apocalypse   2
# major   2
# growing up   2
# traveling salesman   2
# publisher   2
# barbed wire   2
# underwater   2
# corporate greed   2
# economy   2
# greed   2
# mentor   2
# dalai lama   2
# tibet   2
# pole dancer   2
# running   2
# cbs   2
# middle east   2
# normandy   2
# cross country   2
# u.s. president   2
# rocket   2
# parole   2
# aspiring actor   2
# birth   2
# orgy   2
# sexual fantasy   2
# deception   2
# south america   2
# pickpocket   2
# police sergeant   2
# blizzard   2
# perfume   2
# name calling   2
# penis slur   2
# final battle   2
# blood vomiting   2
# greece   2
# southern u.s.   2
# missing person   2
# parallel universe   2
# groom   2
# montana   2
# contract killer   2
# taxi   2
# firefighter   2
# main character dies   2
# cure   2
# newscaster   2
# rangefinder   2
# curse   2
# year 1949   2
# pitcher   2
# nypd   2
# autistic child   2
# child in danger   2
# grave   2
# playing piano   2
# producer   2
# evangelist   2
# wyoming   2
# amputee   2
# war hero   2
# hijacking   2
# plane   2
# non statutory female on male rape   2
# sexual harassment   2
# 21st century   2
# engineer   2
# special forces   2
# anthropologist   2
# disfigurement   2
# no man's land   2
# lolita   2
# nymphet   2
# older man young girl relationship   2
# mob hit   2
# russian revolution   2
# japanese soldier   2
# losing   2
# poker   2
# interrogation   2
# lie   2
# talking to one's self in a mirror   2
# wrestling   2
# balladeer   2
# crusades   2
# fiance   2
# sports agent   2
# gothic   2
# based on stage musical   2
# cinderella   2
# witch   2
# negotiation   2
# tough guy   2
# love at first sight   2
# end of the world   2
# meeting   2
# strategy   2
# quarantine   2
# erotic thriller   2
# hezbollah   2
# libya   2
# hit in the crotch   2
# innocence   2
# indiana   2
# american actress playing british character   2
# insurance   2
# map   2
# fashion show   2
# queens new york city   2
# internal affairs   2
# aunt   2
# faked death   2
# summer camp   2
# american civil war   2
# limousine driver   2
# baby boy   2
# kidnapping a child   2
# 17th century   2
# alien invasion   2
# panties pulled down   2
# quadriplegic   2
# burglar   2
# kuwait   2
# soviet union   2
# woman slaps a man   2
# science   2
# one last job   2
# opposites attract   2
# kissing   2
# sikh   2
# rambo   2
# laboratory   2
# insomnia   2
# mechanic   2
# sex offender   2
# contract   2
# sexual attraction   2
# songwriter   2
# explosive   2
# miami florida   2
# liverpool   2
# connecticut   2
# german soldier   2
# partisan   2
# surgeon   2
# guard   2
# 12 step program   2
# battle of the sexes   2
# womanizer   2
# defense lawyer   2
# urban legend   2
# homicide   2
# media   2
# contest   2
# master   2
# deportation   2
# spanking   2
# shot multiple times   2
# intellectual property   2
# cooking   2
# baseball player   2
# antarctica   2
# website   2
# self help guru   2
# mayan   2
# love across time   2
# parallel time   2
# young love   2
# music group   2
# underdog   2
# paris france   2
# generation y   2
# mute   2
# aids   2
# king henry viii   2
# resort   2
# weapon   2
# buddhist   2
# electronic tag   2
# house arrest   2
# watching someone   2
# hunt   2
# nomad   2
# crow   2
# kissing while having sex   2
# fate   2
# co worker   2
# rock star   2
# african american lesbian   2
# lesbian couple   2
# jamaica   2
# football movie   2
# boxing match   2
# hawaiian shirt   2
# memoir   2
# trap   2
# girlfriend   2
# tragic hero   2
# demon   2
# high school football   2
# newspaper clipping   2
# stallion   2
# racial slur   2
# crush   2
# law school   2
# holocaust   2
# hasselblad camera   2
# medium format camera   2
# childbirth   2
# midlife crisis   2
# u.s. navy   2
# provence   2
# physical abuse   2
# stepfather   2
# barrio   2
# gang war   2
# cannes   2
# cholera   2
# raid   2
# ice   2
# electrocuted in bathtub   2
# guantanamo   2
# baby rattle   2
# famous line   2
# reading   2
# war crime   2
# executive   2
# racial discrimination   2
# colon in title   2
# high school teacher   2
# mentor protege relationship   2
# responsibility   2
# memory loss   2
# head coach   2
# police partner   2
# second chance   2
# south carolina   2
# passion   2
# corrupt police   2
# death of sister   2
# immortality   2
# playground   2
# self injury   2
# football practice   2
# machine   2
# clinical trial   2
# neuropharmacology   2
# side effect   2
# truth   2
# cave   2
# dodge viper   2
# new year's eve   2
# forensics   2
# mine   2
# flashback within a flashback   2
# split screen   2
# clone   2
# ex wife   2
# montreal   2
# snowstorm   2
# black soldier   2
# military uniform   2
# speakeasy   2
# crime lord   2
# dead body   2
# dead body in a freezer   2
# disarming someone   2
# world cup   2
# villa   2
# marriage proposal   2
# editor   2
# shot in the head   2
# rap music   2
# hockey   2
# estranged wife   2
# bolivia   2
# celebrity   2
# secret society   2
# drawing   2
# coroner   2
# gay son   2
# tech noir   2
# gay lead character   2
# evil   2
# mozart   2
# bechdel test passed   2
# wild west   2
# death of soldier   2
# war trauma   2
# diplomat   2
# suffering   2
# convertible   2
# duel   2
# child in peril   2
# troll   2
# inspiration   2
# holiday   2
# turn of the century   2
# father   2
# attack   2
# pedophilia   2
# championship   2
# harvard   2
# physics   2
# 1988 winter olympics   2
# ski jumper   2
# winter olympics   2
# phone sex   2
# orchestral music score   2
# library   2
# custody battle   2
# identical twins   2
# ira   2
# irish american   2
# manuscript   2
# biker gang   2
# pistol   2
# trailer   2
# murder investigation   2
# brothel   2
# kung fu   2
# poem   2
# heavyweight champion   2
# haunted by the past   2
# cowboy boots   2
# high school dance   2
# transplant   2
# kansas city   2
# soap opera   2
# friar   2
# reference to jesus christ   2
# policeman   2
# absent father   2
# courtesan   2
# female lead   2
# gallipoli   2
# surrealism   2
# disability   2
# glass   2
# truck   2
# parole officer   2
# ambiguous ending   2
# little league baseball   2
# bipolar disorder   2
# gang violence   2
# woman on top   2
# autism   2
# ufo   2
# cell phone   2
# e mail   2
# german shepherd   2
# digging   2
# caretaker   2
# wheelchair   2
# mafia boss   2
# hometown   2
# campaign   2
# sibling   2
# gay rights   2
# biblical   2
# roman soldier   2
# store   2
# vinyl   2
# self defense   2
# playing against type   2
# bishop   2
# lady   2
# 18th birthday   2
# alternate reality   2
# dinner   2
# gay kiss   2
# foreign language adaptation   2
# ex boyfriend ex girlfriend relationship   2
# voice over narration   2
# rat   2
# bordeaux   2
# hideout   2
# fascist   2
# protection   2
# handcuffs   2
# sperm   2
# basement   2
# inner city   2
# shrine   2
# cruelty   2
# barbershop   2
# florist   2
# construction   2
# dialogue driven   2
# alter ego   2
# tailor   2
# reference to facebook   2
# escaped convict   2
# classic literature   2
# denmark   2
# mysterious event   2
# revolutionary   2
# physicist   2
# cross dressing   2
# atrocity   2
# hitman   2
# based on the bible   2
# star   2
# tutor   2
# dance contest   2
# illusionist   2
# gunshot   2
# jane austen   2
# auction   2
# education   2
# malpractice   2
# babysitting   2
# possession   2
# single parent   2
# beauty salon   2
# monastery   2
# sword and shield   2
# city name in title   2
# homophobia   2
# convict   2
# recovery   2
# hypnotherapy   2
# lost painting   2
# explicit sex   2
# mob   2
# norway   2
# van   2
# prosecutor   2
# flying   2
# machismo   2
# magical realism   2
# throat slitting   2
# korea   2
# lifeguard   2
# chariot race   2
# title based on song   2
# tennessee   2
# hiking   2
# tennis   2
# beating   2
# chicago illinois   2
# false identity   2
# femme fatale   2
# spying   2
# accidental death   2
# 12 year old   2
# nipples visible through clothing   2
# modern day adaptation   2
# promiscuous woman   2
# country club   2
# colorado   2
# cro magnon   2
# lawn mower   2
# worker   2
# what happened to epilogue   2
# photograph   2
# behind enemy lines   2
# french revolution   2
# englishman   2
# flogging   2
# cheating   2
# postal worker   2
# semi autobiographical   2
# chess   2
# dysfunctional marriage   2
# college campus   2
# gossip   2
# skateboard   2
# wallet   2
# meaning of life   2
# moral challenge   2
# morality   2
# search for meaning   2
# ten commandments   2
# bunker   2
# disc jockey   2
# bullying   2
# stroke   2
# protective father   2
# imprisonment   2
# homeless man   2
# gold mine   2
# surveyor   2
# classroom   2
# headmaster   2
# real estate   2
# fence   2
# factory   2
# washington d.c.   2
# korean war   2
# mouse   2
# found footage   2
# troubled teen   2
# pain   2
# nebraska   2
# brooklyn bridge   2
# time travel romance   2
# sex addiction   2
# married man   2
# old age   2
# poison   2
# school shooting   2
# hatred   2
# noodles   2
# salary   2
# cameraman   2
# beer   2
# isolated house   2
# high school senior   2
# punishment   2
# solitary confinement   2
# bet   2
# face slap   2
# miracle   2
# political prisoner   2
# shakespeare's othello   2
# deaf   2
# black panties   2
# comeback   2
# luck   2
# candle   2
# neo nazi   2
# violinist   2
# wisconsin   2
# indian american   2
# spelling   2
# spelling bee   2
# entertainer   2
# slacker   2
# race relations   2
# social problem   2
# hipster   2
# gardener   2
# halfway house   2
# schizophrenia   2
# lingerie   2
# materialism   2
# toronto   2
# reference to william shakespeare   2
# medication   2
# sodomy   2
# abuse of power   2
# arizona   2
# dementia   2
# playboy   2
# bar mitzvah   2
# self destructiveness   2
# music business   2
# asperger's syndrome   2
# container   2
# motorboat   2
# ethics   2
# uncle nephew relationship   2
# next door neighbor   2
# principal   2
# martha's vineyard   2
# upper class   2
# full frontal male nudity   2
# hotel room   2
# looking at one's self in a mirror   2
# machinist   2
# record label   2
# neo western   2
# loner   2
# french canadian   2
# police shootout   2
# food in title   2
# title at the end   2
# intolerance   2
# mormon church   2
# waiter   2
# patriarch   2
# true love   2
# new zealand   2
# double life   2
# funeral home   2
# domestic abuse   2
# temptation   2
# sex addict   2
# andy warhol   2
# pills   2
# rio de janeiro brazil   2
# traveling   2
# skinny dipping   2
# nervous breakdown   2
# tween girl   2
# serbian   2
# estrangement   2
# greedy institution   2
# hand job   2
# hugging   2
# east germany   2
# pizza   2
# multiple outcomes   2
# talent   2
# dream sequence   2
# sex change   2
# transsexual   2
# safe   2
# loss   2
# language   2
# recording   2
# race   2
# drug addict   2
# drug addiction   2
# junkie   2
# three sisters   2
# 1910s   2
# moon   2
# monk   2
# praying   2
# old man   2
# oklahoma city   2
# concierge   2
# policewoman   2
# human branding   2
# cabin   2
# dock   2
# incest   2
# meth   2
# buried alive   2
# evacuation   2
# financial crisis   2
# tragic love   2
# farmhouse   2
# running out of gas   2
# trapeze   2
# trapeze artist   2
# radio station   2
# happiness   2
# honesty   2
# indifference   2
# dole   2
# northern england   2
# unemployment   2
# homoeroticism   2
# music school   2
# deer   2
# city   2
# small town life   2
# actress shares first name with character   2
# pakistani   2
# trailer park   2
# 15 year old   2
# paternity   2
# bound and gagged   2
# near future   2
# mexican immigrant   2
# march   2
# skinhead   2
# exclamation point in title   2
# six year old   2
# animal in title   2
# adolescence   2
# wales   2
# ex convict   2
# storytelling   2
# yorkshire   2
# insecurity   2
# personal ad   2
# undressing   2
# invention   2
# older man younger man relationship   2
# cheating husband   2
# forest   2
# telephone call   2
# twenty something   2
# time machine   2
# based on short film   2
# misfit   2
# dare   2
# taliban   2
# low budget film   2
# dialogue driven storyline   2
# asian american   2
# coming out   2
# 1190s   1
# archer   1
# king of england   1
# wet   1
# charles dickens   1
# star died before release   1
# automaton   1
# mechanical   1
# steampunk   1
# joy   1
# running away   1
# sadness   1
# evil queen   1
# snow white   1
# ronin   1
# shogun   1
# high tech   1
# masked man   1
# black hole   1
# saving the world   1
# deformed baby   1
# premature aging   1
# cruise   1
# black smoke   1
# japanese military   1
# japanese navy   1
# sunday   1
# ancient greece   1
# conquest   1
# greek myth   1
# survivalist   1
# hamster   1
# superpower   1
# full moon   1
# transformation   1
# black u.s. president   1
# cynicism   1
# false promise of the american dream   1
# napoleonic wars   1
# royal navy   1
# bear attack   1
# cauterizing a wound   1
# ark   1
# noah's ark   1
# wrath of god   1
# darwin   1
# drover   1
# fish   1
# christ figure   1
# messiah   1
# saviour   1
# social commentary   1
# embarrassment   1
# steel helmet   1
# u.s. marine   1
# dark fantasy   1
# sole survivor   1
# natural disaster   1
# san andreas fault   1
# american revolution   1
# standoff   1
# aviation   1
# spruce goose   1
# test flight   1
# commander   1
# robot battle   1
# elf   1
# hobbit   1
# african americans   1
# boxing gym   1
# rumble in the jungle   1
# 12th century   1
# crusader   1
# international cooperation   1
# left for dead   1
# space habitat   1
# celebrity criminal   1
# public enemy number one   1
# popcorn   1
# rogue agent   1
# witness protection program   1
# dynamite   1
# n word   1
# 15th century   1
# gypsy   1
# paris   1
# victor hugo   1
# based on children's book   1
# igloo   1
# sierra leone   1
# sex in an airplane   1
# iraqi   1
# political military conspiracy   1
# weapon of mass destruction   1
# extradition   1
# japanese tourist   1
# abusive stepfather   1
# attempted rape   1
# food shortage   1
# starving child   1
# helicopter   1
# somali   1
# abu dhabi   1
# united arab emirates   1
# orc   1
# evil wizard   1
# wizard   1
# power outage   1
# chimpanzee   1
# when animals attack   1
# daydream   1
# snow leopard   1
# boston   1
# american actor playing foreigner   1
# affection   1
# religion versus science   1
# universe   1
# 23rd century   1
# lava   1
# volcano   1
# radiation sickness   1
# radioactive contamination   1
# test launch   1
# jockey   1
# seabiscuit   1
# device   1
# tornado   1
# talking to inanimate object   1
# ex soldier   1
# hijacker   1
# stalingrad   1
# geisha   1
# death personified   1
# fear of death   1
# car explosion   1
# editing   1
# frozen time   1
# obese man   1
# remote control   1
# stopped time   1
# cartoonist   1
# zodiac   1
# zodiac killer   1
# answer to prayer   1
# breast expansion   1
# pleading with god   1
# walking on water   1
# fight to the death   1
# self survival   1
# social worker   1
# astronomer   1
# comet   1
# news broadcast   1
# tv broadcast   1
# wounded soldier   1
# blind   1
# brutality   1
# brainwashed assassin   1
# pin   1
# ruby   1
# soul   1
# soul mate   1
# giving birth   1
# ultrasonography   1
# survival tactics   1
# blockade   1
# missile   1
# collapsing tunnel   1
# weimaraner   1
# based on stage musical based on film   1
# film director   1
# postman   1
# damselfish   1
# ocean habitat   1
# ocean life   1
# razorfish   1
# spider crab   1
# lava bomb   1
# mount vesuvius   1
# pompeii   1
# nobel prize   1
# scar   1
# unnecessary guilt   1
# criminal profile   1
# madman   1
# tabloid reporter   1
# tragic villain   1
# aviator   1
# little girl   1
# the little prince   1
# tv dance show   1
# construction site   1
# man without a country   1
# based on comic   1
# dc arrowverse   1
# k2   1
# pop chart   1
# cop   1
# black september   1
# munich olympics   1
# refugee   1
# hypochondriac   1
# 1860s   1
# schoolteacher   1
# siam   1
# burned alive   1
# castration   1
# olympus   1
# torture device   1
# crash survivor   1
# child with gun   1
# invulnerability   1
# manifestation   1
# spacecraft   1
# craigslist   1
# bomb making   1
# saudi arabia   1
# stabbed in the crotch   1
# 14th century   1
# tyranny   1
# american abroad   1
# u.s. military   1
# usmc   1
# car race   1
# race car   1
# race car driver   1
# rookie   1
# pact   1
# crop circle   1
# glass of water   1
# loss of faith   1
# scalping   1
# bedtime story   1
# eagle   1
# stuttering   1
# air cavalry   1
# dog saved from a fire   1
# multiple narrators   1
# publishing house   1
# cavalry   1
# art expert   1
# nazi stolen art   1
# estranged couple   1
# dracula   1
# tarantula   1
# turk   1
# himalaya   1
# music industry   1
# cybercrime   1
# analyst   1
# nuclear bomb   1
# nuclear weapons   1
# scepter   1
# breast   1
# prefect   1
# cbs news   1
# tobacco   1
# whistleblower   1
# coast guard   1
# oil tanker   1
# sinking ship   1
# jordan   1
# killed in action   1
# custom car   1
# illegal street racing   1
# police officer crushed   1
# street racing   1
# cultural conflict   1
# cape kennedy   1
# news footage   1
# reference to christopher columbus   1
# trapped in space   1
# barricade   1
# innkeeper   1
# competing businesses   1
# instant messaging   1
# shop owner   1
# misadventure   1
# suitcase   1
# rubble   1
# wellesley college   1
# business tycoon   1
# mayoral candidate   1
# penthouse   1
# reference to star trek   1
# guerrilla   1
# soviet   1
# wolverine   1
# campaigning   1
# candidate   1
# foot chase   1
# pipeline   1
# anti establishment   1
# dark humor   1
# multiple personality disorder   1
# marshall university   1
# workhouse   1
# mount everest   1
# mountain climbing   1
# scent   1
# sense of smell   1
# smell   1
# wyatt earp   1
# colombian drug cartel   1
# child fugitive   1
# martial art   1
# silk road   1
# state dinner   1
# shot in the crotch   1
# spartan   1
# warrior   1
# pet name in title   1
# death row inmate   1
# healing   1
# missing wife   1
# murder suspect   1
# army cid   1
# woman in military   1
# controlled environment   1
# fictional reality show   1
# hidden camera   1
# innocence lost   1
# simulated reality   1
# ancient egypt   1
# hebrew   1
# close up of breasts   1
# hot shot   1
# racing   1
# stock car driver   1
# emotional balance   1
# indonesia   1
# inner peace   1
# bowling   1
# in medias res   1
# grace   1
# western u.s.   1
# city by night   1
# driving at night   1
# contagion   1
# infection   1
# police corruption   1
# toxic waste   1
# news anchor   1
# newscast   1
# tv journalism   1
# covert analyst   1
# stock market   1
# based on real person   1
# female inventor   1
# mop   1
# sales pitch   1
# woman holding a shotgun   1
# ethiopia   1
# marksman   1
# machine gun   1
# police vigilantism   1
# nation   1
# rugby   1
# political conspiracy   1
# baseball scout   1
# vigilantism   1
# columnist   1
# los angeles times   1
# wearing a traffic cone as a hat   1
# caddy   1
# golf course   1
# rolling stone magazine   1
# smoking marijuana   1
# framed   1
# goddess   1
# sinbad   1
# venezuela   1
# black dahlia   1
# three star general   1
# black and white photograph   1
# drawing with blood   1
# falling through ice   1
# red haired woman   1
# hello kitty   1
# female removes her clothes   1
# lieutenant colonel   1
# professional rivalry   1
# televangelist   1
# death of child   1
# sniper rifle   1
# college football   1
# surrender   1
# witness protection   1
# tuskegee airmen   1
# deal with the devil   1
# male nanny   1
# wrestling match   1
# actor playing multiple roles   1
# unsubtitled foreign language   1
# virginia   1
# clark kent   1
# year 1978   1
# the bronx   1
# order   1
# internship   1
# fall   1
# heart surgeon   1
# argentina   1
# lion   1
# railway   1
# poacher   1
# execution by hanging   1
# los angeles police department   1
# miscarriage of justice   1
# wrongful conviction   1
# cold fusion   1
# outrunning explosion   1
# san francisco giants   1
# based on stage musical based on novel   1
# mask   1
# intrigue   1
# confederacy   1
# prequel   1
# stonewall jackson   1
# blanket   1
# feather   1
# sleepover   1
# burlesque   1
# small town girl   1
# court martial   1
# organ donor   1
# repeating history   1
# shoes   1
# reference to anastasia romanov   1
# romanov   1
# death of main character   1
# eiffel tower paris   1
# two suitors   1
# boston massachusetts   1
# imperial japan   1
# japanese army   1
# deal   1
# poker player   1
# reference to frederic chopin   1
# reference to johannes brahms   1
# cat and mouse   1
# pan am   1
# football video game   1
# hill   1
# tropical island   1
# andy kaufman   1
# car bomb   1
# card cheat   1
# cash   1
# gambling syndicate   1
# forks washington   1
# protecting a woman   1
# title same as book   1
# modern minstrel   1
# contamination   1
# environmental issue   1
# working single mother   1
# dangerous friend   1
# monster as victim   1
# custody   1
# fashion photographer   1
# little red riding hood   1
# robber   1
# anti hero   1
# blocked road   1
# zookeeper   1
# time capsule   1
# statistics   1
# voice over   1
# monkey   1
# post traumatic stress   1
# marital infidelity   1
# wife's lover murdered by husband   1
# cia agent   1
# u.s. ambassador   1
# feminism   1
# kicked in the testicles   1
# falling through a glass roof   1
# negotiator   1
# life insurance policy   1
# paradise   1
# detroit tigers   1
# perfect game   1
# detective inspector   1
# bouncer   1
# private dancer   1
# military crime   1
# necklace yanked off   1
# interpol   1
# government agent   1
# oceanographer   1
# limousine   1
# one night   1
# dauphin   1
# wartime rape   1
# closet   1
# psychiatric hospital   1
# real life sisters playing sisters   1
# museum   1
# natural history museum   1
# news reporter   1
# bush administration   1
# new york times   1
# planet invasion   1
# year 2046   1
# female bounty hunter   1
# reality show   1
# magic spell   1
# children's tv show   1
# chun li   1
# crime fighter   1
# clan   1
# scottish highlands   1
# year 1743   1
# inspired by radio program   1
# pirate broadcasting   1
# pirate radio   1
# pirate radio station   1
# interlinked stories   1
# mind uploading   1
# brownstone   1
# panic room   1
# child murderer   1
# extraterrestrial   1
# brothers hugging   1
# parole violation   1
# small western town   1
# cable guy   1
# foreplay   1
# housemaid   1
# borg   1
# borg sphere   1
# confederate   1
# independence day   1
# bravery   1
# medal of honor   1
# military life   1
# unreliable flashback   1
# douglas macarthur   1
# inchon   1
# college professor   1
# supreme court   1
# brother   1
# list   1
# child abduction   1
# narc   1
# narcotics   1
# basketball coach   1
# feud   1
# road rage   1
# lift skirt   1
# short shorts   1
# aging rocker   1
# explosives expert   1
# driving range   1
# winnebago   1
# arms tied overhead   1
# damsel in distress   1
# courthouse   1
# heavy rain   1
# pledge   1
# porcupine   1
# quaker   1
# chrysanthemum   1
# empress   1
# living dead   1
# u.s. embassy   1
# year 1979   1
# one armed man   1
# prank   1
# temple   1
# 1890s   1
# hired gun   1
# johnson county war   1
# collar   1
# death of brother   1
# seeing dead people   1
# talking with the dead   1
# chicken   1
# rooster   1
# cleopatra   1
# villager   1
# columbia university   1
# lecture   1
# mothman   1
# point pleasant west virginia   1
# immorality   1
# ukrainian   1
# self expression   1
# white rapper   1
# able to see the dead   1
# drunk wife   1
# fbi investigation   1
# sitka alaska   1
# perversion   1
# outnumbered   1
# softball   1
# competitiveness   1
# creator   1
# entrepreneur   1
# facebook   1
# blog   1
# brooklyn dodgers   1
# major league baseball   1
# siberian husky   1
# sled dog   1
# reference to ben affleck   1
# reference to brad pitt   1
# reference to george clooney   1
# reference to jack nicholson   1
# french and indian war   1
# rhythm and blues   1
# inner beauty   1
# adult as child   1
# navigator   1
# dance competition   1
# dance lesson   1
# count   1
# defense attorney   1
# illusion   1
# jaguar   1
# solar eclipse   1
# dodgeball   1
# portrait   1
# soccer game   1
# musical quartet   1
# insurance company   1
# slave ship   1
# slave trade   1
# environment   1
# gas chromatograph   1
# may december romance   1
# rockefeller center   1
# the doors   1
# clown costume   1
# party planner   1
# soap opera actress   1
# good deed   1
# baltimore orioles   1
# boston red sox   1
# ups   1
# world series   1
# nerd   1
# mourning   1
# job offer   1
# roller coaster   1
# slow motion action scene   1
# slow motion sequence   1
# hiv positive   1
# roommate   1
# easter   1
# luminol   1
# omen   1
# catholic guilt   1
# epilepsy   1
# italian american   1
# basic training   1
# reference to shakespeare's hamlet   1
# female in a shower   1
# premarital sex   1
# woman wearing a miniskirt   1
# camelot   1
# excalibur   1
# grandson   1
# based on article   1
# massage therapist   1
# regaining sight   1
# probation   1
# lap dance   1
# lap dancing   1
# striptease   1
# versailles   1
# enforcer   1
# arctic circle   1
# volunteer   1
# tribute   1
# mineral   1
# liar   1
# literary agent   1
# magical tree   1
# hit squad   1
# computer virus   1
# cyberpunk   1
# fight the system   1
# bosnia   1
# fox   1
# war criminal   1
# blood brother   1
# dynasty   1
# stabbing a woman   1
# kazakhstan   1
# closed ecological system   1
# perpetual winter   1
# population control   1
# back from the dead   1
# ancient india   1
# jumping on a bed   1
# librarian   1
# pregnant woman in bathtub   1
# boxing arena   1
# boxing manager   1
# directed by co star   1
# alliance   1
# challenge   1
# martial arts master   1
# circus vargas   1
# intimate partner homicide   1
# mysterious man   1
# emergency room   1
# cover band   1
# fired from a job   1
# heavy metal   1
# tribute band   1
# acrophobia   1
# past life regression   1
# psychological testing   1
# right hand man   1
# scientology   1
# syracuse university   1
# montage   1
# philadelphia   1
# bank robbery   1
# criminal gang   1
# expecting twins   1
# embassy   1
# formula 1   1
# sex with a nurse   1
# coincidence   1
# fictional game show   1
# fictional quiz show   1
# multiple storyline   1
# prosthetics   1
# tail   1
# health care   1
# car breakdown   1
# jeep   1
# medical scrubs   1
# purple gloves   1
# turtle   1
# christmas season   1
# release from prison   1
# bust   1
# washington state   1
# exorcist   1
# seminary   1
# martial arts school   1
# wing chun   1
# saint   1
# spanish civil war   1
# starts with narration   1
# football star   1
# left tackle   1
# arkansas   1
# fashion industry   1
# publishing   1
# blackjack   1
# card counting   1
# massachusetts institute of technology   1
# triple crown   1
# disney   1
# reference to walt disney   1
# suppression of emotion   1
# black history   1
# nation of islam   1
# ex partner   1
# loud sex   1
# warsaw ghetto   1
# bethlehem   1
# nazareth   1
# film camera   1
# leica camera   1
# federal bureau of investigation   1
# fatal attraction   1
# interspecies romance   1
# bomb shelter   1
# cuban missile crisis   1
# naive man   1
# karma   1
# publicist   1
# graveyard   1
# murder trial   1
# labor   1
# labor union   1
# psychic vision   1
# staff physician   1
# chronic traumatic encephalopathy   1
# concussion   1
# football player   1
# pathologist   1
# college girl   1
# pittsburgh pennsylvania   1
# naked dead man   1
# bombardier   1
# employee employer relationship   1
# wake   1
# queen of england   1
# ice cube   1
# waco texas   1
# gun fu   1
# plastic surgery   1
# skyscraper   1
# tightrope walker   1
# radio flyer   1
# stepfather stepson relationship   1
# greenland   1
# roof   1
# mussolini   1
# austrian   1
# bushwhacker   1
# male ponytail   1
# eternity   1
# tree   1
# tree of life   1
# ice cream truck   1
# art collector   1
# bull riding   1
# cold war era   1
# lance corporal   1
# flash mob   1
# newcastle united   1
# air traffic control   1
# air traffic controller   1
# female bodybuilder   1
# teaching oneself to read   1
# brain tumor   1
# psionic power   1
# compassion   1
# andes mountains   1
# cartographer   1
# smithsonian   1
# crotch shot   1
# ambulance   1
# antique shop   1
# asian dragon   1
# korean   1
# green beret   1
# teacher inspires students   1
# teaching   1
# tied up while barefoot   1
# plantation   1
# airline   1
# lobby boy   1
# based on multiple works   1
# mysterious stranger   1
# altering history   1
# amateur radio   1
# ham radio   1
# paranormal phenomena   1
# life support   1
# voice recording   1
# race against time   1
# venture capital   1
# serial murder   1
# seven deadly sins   1
# ballistics   1
# boxing trainer   1
# women boxing   1
# summer love   1
# hannah montana   1
# shrimper   1
# downsizing   1
# time loop   1
# sheep   1
# sheepdog   1
# couple   1
# intimacy   1
# marriage counseling   1
# middle age couple   1
# breakup   1
# bare butt   1
# four brothers   1
# bottle   1
# jogging   1
# racehorse   1
# zebra   1
# septicemia   1
# italian stereotype   1
# man in a swimsuit   1
# verona italy   1
# college basketball   1
# national championship   1
# ncaa   1
# juarez mexico   1
# u.s. mexico border   1
# war on drugs   1
# boxing training   1
# hit by a pickup truck   1
# resuscitation   1
# eyeglasses   1
# dance crew   1
# bikini   1
# female surfer   1
# surfing contest   1
# swimsuit   1
# family drama   1
# political campaign   1
# bus stop   1
# community college   1
# scooter   1
# speech class   1
# ballroom   1
# dance teacher   1
# hollywood california   1
# sitcom   1
# alliterative title   1
# rag doll   1
# liberal   1
# rebreather   1
# electronic devices   1
# gynecologist   1
# little black book   1
# plan   1
# set up   1
# evidence   1
# fingerprints   1
# murder weapon   1
# disk   1
# floppy disk   1
# pfizer   1
# viagra   1
# zoloft   1
# dna   1
# interspecies sex   1
# brother in law   1
# fort   1
# trade   1
# padded cell   1
# cloning   1
# abusive boyfriend   1
# guest   1
# coastal town   1
# iceland   1
# winter storm   1
# communications   1
# ambiguity   1
# truck explosion   1
# loan   1
# merchant   1
# pound of flesh   1
# french riviera   1
# paddock   1
# supercross   1
# winning   1
# illustrator   1
# armor   1
# long title   1
# train robbery   1
# qing dynasty   1
# stabbed with a bayonet   1
# war violence   1
# mob boss   1
# african national congress   1
# film starts with text   1
# 20th century   1
# association   1
# fifa   1
# grace kelly   1
# hollywood star   1
# monaco   1
# art forgery   1
# picture framer   1
# paradox   1
# celibacy   1
# synagogue   1
# american president   1
# political drama   1
# washington post the newspaper   1
# broken nose   1
# kgb   1
# playboy mansion   1
# sistine chapel   1
# gulf war veteran   1
# gangsta rap   1
# nwa   1
# lost   1
# newborn baby   1
# opera singer   1
# platonic marriage   1
# banking   1
# finance   1
# ice hockey   1
# thrown through a window   1
# guardian   1
# gentleman   1
# georgian   1
# leather dress   1
# arrest   1
# mental patient   1
# scheme   1
# inspired by documentary   1
# presidential campaign   1
# year 2002   1
# lama   1
# tibetan   1
# starlet   1
# oncology   1
# sick child   1
# comma in title   1
# name in title   1
# talk show host   1
# magistrate   1
# mosque   1
# detention   1
# brain capacity   1
# fictional drug   1
# taking a pill   1
# punching a heavy bag   1
# tied to a tree   1
# turkey   1
# imaginary son   1
# sound barrier   1
# space program   1
# u.s. air force   1
# u.s. space program   1
# earl of oxford   1
# story within the story   1
# talking animal   1
# retrofuturism   1
# heir   1
# bank robber   1
# crime spree   1
# adopted son   1
# mars the planet   1
# shot in the chest   1
# shot in the heart   1
# gay republican   1
# beard   1
# eiffel tower   1
# ritual   1
# stew   1
# based on opera   1
# walking wounded   1
# muse   1
# theater   1
# ex cop   1
# murder of wife   1
# leonardo da vinci   1
# childhood trauma   1
# airborne troops   1
# operation market garden   1
# panzer   1
# paratrooper   1
# bodybuilder   1
# punch into the camera   1
# reference to julia roberts   1
# company   1
# corporate takeover   1
# new boss   1
# 1880s   1
# table broken in fight   1
# delaware   1
# erotica   1
# necklace   1
# safecracker   1
# wine dealer   1
# grindhouse   1
# fancy restaurant   1
# male actor playing a female character   1
# buick   1
# last will and testament   1
# savant   1
# hmong   1
# cabinet meeting   1
# pop singer   1
# secret service agent   1
# black servant   1
# chocolate pie   1
# jackson mississippi   1
# writing a novel   1
# news leak   1
# whistleblowing   1
# wikileaks   1
# corrupt judge   1
# tax evasion   1
# tough cop   1
# white suit   1
# year 1930   1
# coin toss   1
# tracking device   1
# book publishing   1
# calorie counting   1
# rabbit costume   1
# chocolate   1
# chocolate shop   1
# cigar smoking   1
# tombstone arizona   1
# arrogance   1
# kennel   1
# post traumatic stress disorder   1
# reference to peter pan   1
# stage play   1
# stubbornness   1
# leadership   1
# pushed out a window   1
# smothered with a pillow   1
# telescope   1
# capitalism   1
# cuban american   1
# cuban refugee   1
# abdication   1
# forbidden city   1
# republic   1
# contraband   1
# jeans   1
# pants   1
# action hero   1
# forced prostitution   1
# one man army   1
# black and white segues into color   1
# color   1
# infanticide   1
# camera shot from inside human body   1
# evil man   1
# cellist   1
# prodigy   1
# rhapsody   1
# british royal family   1
# queen elizabeth i   1
# pearl harbor   1
# escape from prison   1
# prison cell search   1
# wrongful imprisonment   1
# incestuous relationship   1
# teenage daughter   1
# zamboni   1
# porn actor in mainstream movie   1
# don juan   1
# coin collector   1
# surfboard   1
# hacking   1
# harmonium   1
# pudding   1
# champion   1
# golf tournament   1
# nostalgia   1
# moral dilemma   1
# nosebleed   1
# forced to strip   1
# porn actress   1
# scantily clad female   1
# based on a true story   1
# limerick   1
# cleveland browns   1
# linebacker   1
# nfl   1
# team owner   1
# john wilkes booth   1
# lincoln assassination   1
# skateboarder   1
# skateboarding   1
# surf   1
# trapped in a mine   1
# return home   1
# ireland   1
# irish civil war   1
# irish free state   1
# sinn fein   1
# iraq war   1
# thesis   1
# bangkok   1
# train wreck   1
# rape victim   1
# sexual humiliation   1
# fabrication   1
# fake   1
# hoax   1
# wigger   1
# speed   1
# whiskey   1
# lesbian cunnilingus   1
# university of oregon   1
# mercury theatre   1
# opening night   1
# antique   1
# argentine   1
# drug trafficking   1
# no panties   1
# costume drama   1
# napoleon   1
# napoleon bonaparte   1
# wire fu   1
# benzedrine   1
# cactus   1
# ...
# sex slavery   1
# sex tourism   1
# sydney australia   1
# hinduism   1
# marriage engagement   1
# coastline   1
# con   1
# courier   1
# long con   1
# olympic games   1
# comic relief   1
# state flag   1
# camera focus on female butt   1
# art class   1
# police investigation   1
# porn star   1
# black militant   1
# frustration   1
# pizza parlor   1
# pizzeria   1
# shoe shiner   1
# reverse chronology   1
# spitting   1
# sushi   1
# drug use   1
# cross   1
# doused with gasoline   1
# psychosis   1
# art thief   1
# male star appears nude   1
# boston marathon   1
# marathon   1
# miracles   1
# kissing someone's boot   1
# midsummer   1
# telling someone to shut up   1
# valet   1
# minimal cast   1
# palestine   1
# robe   1
# female criminal   1
# hooker   1
# curiosity   1
# exploitation   1
# freak   1
# physical deformity   1
# fda   1
# gay community   1
# hiv   1
# miners strike   1
# awkward boy   1
# shy kid   1
# water park   1
# misogyny   1
# new friend   1
# brumby   1
# abusive mother   1
# adopted daughter   1
# perfection   1
# sadistic cruelty   1
# art model   1
# nude model   1
# nazi germany   1
# track and field   1
# catfight   1
# dominatrix   1
# attraction   1
# witchcraft   1
# linguistics professor   1
# reference to angels in america the play   1
# pyramid   1
# kissing a dead body   1
# repeated dialogue   1
# sex in pool   1
# spring break   1
# cleaning a swimming pool   1
# male male kiss   1
# community center   1
# baltimore colts   1
# crime scene cleanup   1
# queen of sheba   1
# ambulance driver   1
# socialist   1
# sheriff of nottingham   1
# traitor   1
# television station   1
# tv show   1
# flatulence   1
# menstrual blood   1
# nursing school   1
# loudmouth   1
# money laundering   1
# solitude   1
# catholic church   1
# flat tire   1
# fantasy life   1
# teenage crush   1
# pronounced dead   1
# bicycle   1
# new neighbor   1
# yard sale   1
# private investigator   1
# tycoon   1
# alienation   1
# conscience   1
# urban gothic   1
# existentialism   1
# smear campaign   1
# comic book artist   1
# iphone   1
# individual versus society   1
# caper   1
# escapade   1
# new orleans louisiana   1
# hitchhiking   1
# truck driver   1
# fable   1
# cola   1
# ice cream cone   1
# african american policeman   1
# demo tape   1
# directed by cast member   1
# grieving father   1
# guitar player   1
# abduction   1
# individualism   1
# mina   1
# legs   1
# repair shop   1
# actor playing himself   1
# boots   1
# womb   1
# firefly   1
# retired actress   1
# man slaps a woman   1
# manhunt   1
# brutal cop   1
# thai boxing   1
# girl fight   1
# sailing boat   1
# tent   1
# seaside   1
# promiscuous daughter   1
# sex in a bed   1
# son murders mother   1
# whaling   1
# drug dealing   1
# diet pill   1
# fast motion scene   1
# musical filmmaking   1
# tango   1
# el salvador   1
# reagan administration   1
# war journalism   1
# bailiff   1
# meth lab   1
# speed freak   1
# pregnant schoolgirl   1
# musical prodigy   1
# royal court   1
# soccer star   1
# abandoned by mother   1
# sex trade   1
# teenage prostitution   1
# unpaid bill   1
# breath on mirror   1
# engagement ring   1
# historical fiction   1
# heroine   1
# kindred spirit   1
# flying squad   1
# maori   1
# adult actor playing minor   1
# progeria   1
# reference to spiderman   1
# based on film   1
# obsessive love   1
# androgynous   1
# irish republican army   1
# psychological drama   1
# clown   1
# elephant trainer   1
# interracial sex   1
# escape from jail   1
# acrobat   1
# cripple   1
# biological father   1
# escape attempt   1
# radical   1
# car fire   1
# prophecy   1
# 12 year time span   1
# separated parents   1
# leg spreading   1
# sex in bed   1
# sexy   1
# wild horse   1
# dead children   1
# bdsm   1
# listener   1
# radio talk show   1
# attention deficit disorder   1
# art teacher   1
# homework   1
# tunisia   1
# boudoir   1
# electric chair   1
# haunting   1
# counselor   1
# revenge motive   1
# parenthesis in title   1
# shipyard   1
# siamese twins   1
# tuna   1
# vampire hunter   1
# female bare foot   1
# picket fence   1
# tire   1
# countryside   1
# maryland   1
# rafting   1
# continental congress   1
# declaration of independence   1
# massachusetts   1
# bombing mission   1
# munitions   1
# royal flying corps   1
# wave   1
# chancellor   1
# thomas more   1
# monologue   1
# television network   1
# television news   1
# gallantry   1
# latina   1
# accidental shooting   1
# exploding animal   1
# dunes   1
# goat   1
# gun running   1
# record executive   1
# belgium   1
# congo   1
# 1520s   1
# aztec   1
# spanish colonization   1
# spanish conquest   1
# secret government agency   1
# ski mask   1
# stolen money   1
# baptist church   1
# double murder   1
# pawn   1
# held at gunpoint   1
# sex on table   1
# capital management   1
# financial disaster   1
# investment fraud   1
# management   1
# gay parent   1
# job interview   1
# choking   1
# conservatory   1
# dead girl   1
# granddaughter   1
# storage unit   1
# kindergarten teacher   1
# inter cultural   1
# back to school   1
# sadism   1
# love crime   1
# devil worship   1
# incubus   1
# raped by a demon   1
# satanism   1
# colombian   1
# drug mule   1
# stomach   1
# guardian angel   1
# drug culture   1
# filthy toilet   1
# heroin addict   1
# heroin withdrawal   1
# columbine   1
# columbine high school killings   1
# firearm   1
# cultural revolution   1
# nude bathing   1
# golden retriever   1
# sabotage   1
# elevator   1
# elevator girl   1
# car wash   1
# d.j.   1
# revival   1
# nuremberg   1
# mexican american   1
# religious icon   1
# ashram   1
# salford   1
# kama sutra   1
# first date   1
# farm worker   1
# grasshopper   1
# harvest   1
# house cleaner   1
# street artist   1
# black and white   1
# bathing a baby   1
# ensemble cast   1
# episodic structure   1
# social satire   1
# human becoming an animal   1
# mad scientist   1
# part of trilogy   1
# walrus   1
# hypnosis   1
# freeway   1
# essex   1
# little sister   1
# dance craze   1
# brains   1
# exploding head   1
# swarm behavior   1
# based on a book   1
# based on a novel   1
# made for tv movie   1
# support   1
# front desk   1
# rowing   1
# 1955 chevrolet   1
# peeping tom   1
# reference to brooklyn dodgers   1
# doggystyle sex   1
# rough sex   1
# violent sex   1
# female friendship   1
# new england   1
# dealer   1
# bad cop   1
# eugene oregon   1
# harpooner   1
# thong   1
# testicles   1
# sertao   1
# apple   1
# dude   1
# electroshock therapy   1
# awkwardness   1
# professor of history   1
# satyagraha   1
# unscrupulous builder   1
# beekeeper   1
# bra   1
# poland   1
# rodeo cowboy   1
# narcolepsy   1
# conversations   1
# canadian gothic   1
# paranormal   1
# mennonite   1
# chinese american   1
# lesbian love   1
# bangladesh   1
# buckingham palace   1
# crying man   1
# men's clothing store   1
# call center   1
# network   1
# wilhelm scream   1
# north pole   1
# santa   1
# million man march   1
# bound with duct tape   1
# flash forward   1
# riddle   1
# population   1
# state in title   1
# interracial marriage   1
# miscegenation   1
# showboat   1
# death of loved one   1
# 1850s   1
# dark secret   1
# sin eater   1
# belief   1
# question in title   1
# steel mill   1
# strike   1
# flare gun   1
# soccer team   1
# acceptance   1
# coming out to family   1
# large family   1
# pity   1
# readjusting to civilian life   1
# world war two veteran   1
# sex obsession   1
# female dressed as male   1
# transgender   1
# hearing noises   1
# uninterrupted shot   1
# secret police   1
# stasi   1
# fatherhood   1
# integrity   1
# pool hall   1
# oil field   1
# oil tycoon   1
# wildcatter   1
# belleville   1
# tour de france   1
# very little dialogue   1
# family abandonment   1
# native american reservation   1
# dark horse comics   1
# reference to david letterman   1
# robert crumb   1
# simultaneity   1
# dog fight   1
# 13 year olds   1
# peer pressure   1
# bigotry   1
# crystal meth   1
# search for father   1
# bone   1
# climbing   1
# crevasse   1
# rope   1
# ragtime   1
# seven word title   1
# shoe salesman   1
# wannabe dj   1
# pigeon   1
# auto theft   1
# controversy   1
# ejaculation   1
# mother's boyfriend   1
# phone booth   1
# high school friends   1
# trust   1
# office politics   1
# photo booth   1
# snobbery   1
# butchery   1
# catholic school   1
# deafness   1
# ears   1
# ibiza   1
# stonewall riots   1
# pacific northwest   1
# small town sheriff   1
# cellphone   1
# coke   1
# snorting   1
# alien abduction   1
# carjacking   1
# johannesburg south africa   1
# post apartheid   1
# alibi   1
# profiler   1
# connection   1
# nantucket island   1
# law partner   1
# seaman   1
# yacht   1
# reference to kurt cobain   1
# year 1994   1
# fire investigator   1
# landlord   1
# turpentine   1
# christmas tree   1
# addict   1
# rascal   1
# coffin   1
# one person   1
# teen comedy   1
# nude sunbathing   1
# documentary crew   1
# satanic ritual   1
# the beatles   1
# brother in law sister in law relationship   1
# expectant father   1
# histrionic personality disorder   1
# middle aged woman   1
# off screen rape   1
# auroch   1
# illness   1
# belief in the afterlife   1
# bhutan   1
# weaver   1
# press   1
# reference to howard university   1
# bechdel test failed   1
# repeated event   1
# case   1
# doll   1
# dry humor   1
# only son   1
# school choir   1
# delivery   1
# delivery to wrong address   1
# lunchbox   1
# open ended   1
# unconventional romance   1
# lebanese   1
# monopoly   1
# stenographer   1
# reference to justin bieber   1
# reference to taylor swift   1
# worship   1
# accidental killing   1
# drug humor   1
# profanity   1
# sexual humor   1
# stand up comedy   1
# passive aggression   1
# caramel   1
# suitor   1
# saxophone   1
# antibes   1
# reunion island   1
# film student   1
# unwanted pregnancy   1
# hand to hand combat   1
# kumite   1
# senate   1
# u.s. senate   1
# weed   1
# tennis coach   1
# egg   1
# tap dancing   1
# stamp   1
# commune   1
# defecation   1
# environmentalism   1
# bastille day   1
# jewish nazi   1
# nazism   1
# football game   1
# actor director writer   1
# music score composed by director   1
# tramp   1
# catholicism   1
# music producer   1
# previous marriage   1
# filipino   1
# guerrilla army   1
# trucker   1
# radio dj   1
# girl next door   1
# growing vegetables   1
# high standards   1
# sent away   1
# cyberbullying   1
# 16 year old   1
# tinnitus   1
# city name in series title   1
# place in series title   1
# dogme 95   1
# family secret   1
# alcoholic drink   1
# drunk   1
# german immigrant   1
# war orphan   1
# born in vitro   1
# in vitro fertilization   1
# outer space   1
# central asia   1
# ruler   1
# russian empire   1
# estate   1
# monte carlo   1
# suicidal thoughts   1
# coal mine   1
# videotape   1
# appendicitis   1
# celebration   1
# heist gone wrong   1
# blue bird of happiness   1
# past   1
# exam   1
# northeast region of brazil   1
# portuguese language   1
# female explicit nudity   1
# penetration   1
# hearse   1
# army veteran   1
# slasher   1
# neck breaking   1
# wraparound story   1
# swing   1
# potato   1
# american expatriate   1
# casablanca morocco   1
# gestapo   1
# visa   1
# parapsychologist   1
# greenhouse   1
# plant   1
# hometown hero   1
# philadelphia pennsylvania   1
# night shift   1
# taxi driver   1
# alternate universe   1
# kaiju   1
# orga   1
# dog hit by a car   1
# female in shower   1
# unhappily married woman   1
# heroic military   1
# tarawa   1
# male masturbation   1
# iron lung   1
# sex surrogate   1
# anti choice   1
# christian preach   1
# unprofessional conduct   1
# marine biologist   1
# plumber   1
# siblings   1
# divorced parents   1
# mohawk   1
# anilingus   1
# double cross   1
# two timing   1
# briefs   1
# mumbai riots   1
# to do list   1
# refusing to eat   1
# starving oneself   1
# girls' soccer   1
# soccer coach   1
# israeli   1
# palestinian   1
# camping   1
# hitchhiker   1
# buddhism   1
# evolution   1
# eye   1
# reincarnation   1
# stuck in elevator   1
# reference to led zeppelin   1
# wetting pants   1
# discipline   1
# imperialism   1
# white slavery   1
# inside joke   1
# one man show   1
# san diego california   1
# car racing   1
# model   1
# art exhibition   1
# augmented reality   1
# speculative fiction   1
# locked in a room   1
# looking at self in mirror   1
# automobile association of america   1
# reference to tom jones the singer   1
# older woman younger woman relationship   1
# sex with student   1
# teacher student relationship   1
# youtube   1
# video camera   1
# beatnik   1
# necrophilia   1
# partying   1
# drug abuse   1
# interracial rape   1
# moroccan   1
# xenophobia   1
# singer songwriter   1
# dominance submissiveness   1
# human pet   1
# power exchange   1
# longshoreman   1
# rainy night   1
# towel   1
# chatting   1
# missing person poster   1
# online dating   1
# sexual predator   1
# godparent   1
# closeted lesbian   1
# islamophobia   1
# propaganda   1
# 22 year old   1
# b.a.r.t.   1
# bay area   1
# bambi   1
# mormon missionary   1
# foreign   1
# best friends   1
# reference to matthias steiner   1
# christian propaganda   1
# zealot   1
# toilet   1
# reconciliation   1
# caregiver   1
# first crush   1
# social outcast   1
# taunting   1
# resort town   1
# german expressionism   1
# abusive relationship   1
# tenderloin san francisco   1
# buenos aires argentina   1
# economics   1
# nuclear missile   1
# fur coat   1
# ardennes forest   1
# battle of the bulge   1
# world war two in belgium   1
# drag racing   1
# classified ad   1
# conspiracy theory   1
# kennedy assassination   1
# mock documentary   1
# ephebophile   1
# pederasty   1
# playing hooky   1
# shaving   1
# accused of witchcraft   1
# brooklyn new york city   1
# dialectics   1
# cosmetics   1
# deacon   1
# katana sword   1
# los angeles storm drain   1
# suspense   1
# internet pornography   1
# ganja   1
# kumbh mela   1
# little boy   1
# nude with glasses   1
# abandoned   1
# depot   1
# dwarf   1
# newfoundland new jersey   1
# beer pong   1
# hair   1
# dj   1
# ecstasy the drug   1
# rave   1
# raver   1
# conjoined twins   1
# separation   1
# dart board   1
# ladder factory   1
# brewery   1
# u haul truck   1
# woman wearing a string bikini   1
# practice   1
# destroyed building   1
# group of friends   1
# mental instability   1
# sudden infant death syndrome   1
# cigarette butt   1
# drone   1
# funeral procession   1
# nellis air force base   1
# protest march   1
# filming a wedding   1
# debutante   1
# amazing grace the hymn   1
# skidding truck   1
# 15th birthday   1
# vision of the future   1
# series   1
# tv series   1
# thatcher   1
# implied incest   1
# squeegee   1
# selfishness   1
# huguenot   1
# medicis   1
# protestant   1
# ninja   1
# sequel to cult film   1
# 2020s   1
# one word series title   1
# year 2027   1
# jury   1
# autobiography   1
# overprotective father   1
# social isolation   1
# white trash   1
# oven   1
# stove   1
# thanksgiving dinner   1
# sexual ambiguity   1
# flip phone   1
# rape threat   1
# vulnerable   1
# listening to music   1
# red panties   1
# punching bag   1
# school teacher   1
# full frontal nudity   1
# group shower   1
# authority   1
# boss subordinate relationship   1
# fast food restaurant   1
# gullibility   1
# homecoming queen   1
# overachiever   1
# caught having sex   1
# bisexuality   1
# desi   1
# heritage   1
# reference to babe ruth   1
# shot to death   1
# long distance relationship   1
# parents   1
# student visa   1
# caravan   1
# dominican   1
# teenage pregnancy   1
# half brother   1
# shotgun   1
# new school   1
# storyteller   1
# time paradox   1
# workaholic   1
# rabbit   1
# chewing gum   1
# climbing a tree   1
# translation problems   1
# gunfighter   1
# poker game   1
# year 1879   1
# hot dog bun   1
# needle   1
# upskirt   1
# saloon   1
# saloon singer   1
# full frontal female nudity   1
# menage a trois   1
# reservation   1
# reality spoof   1
# paper bag   1
# august   1
# avoidant personality disorder   1
# emotionally vulnerable   1
# video store clerk   1
# single setting   1
# jazz singer   1
# sexy woman   1
# time manipulation   1
# gardening   1
# shoe   1
# male in bathtub   1
# duplicate earth   1
# solar system   1
# synchronicity   1
# black panther   1
# hells angels   1
# racist cop   1
# country singer   1
# vacuum cleaner   1
# bike   1
# bmx   1
# youth   1
# cult leader   1
# drunken sex   1
# mashed potatoes   1
# pancakes   1
# tequila   1
# acting   1
# idler   1
# poorhouse   1
# learning disability   1
# home invasion   1
# security system   1
# numbers   1
# pattern   1
# using a metal detector on a beach   1
# fast food   1
# food industry   1
# meal   1
# overeating   1
# filmmaker   1
# gay brother   1
# toilet sex   1
# anticipate   1
# dead in absentia   1
# foetus   1
# unreliable narration   1
# female underarm hair   1
# sex in a window   1
# star appears nude   1
# adult returns home   1
# girl with glasses   1
# estranged daughter   1
# stoned   1
# street hustler   1
# mumblecore   1
# misogynist   1
# older brother is bad influence   1
# washington heights manhattan new york city   1
# austin texas   1
# pap smear   1
# car salesman   1
# used car salesman   1
# avatar   1
# tron   1
# gift   1
# upholsterer   1
# gang initiation   1
# gunplay   1
# hazing   1
# shakespeare's romeo and juliet   1
# homeless   1
# changing the future   1
# mariachi   1
# jewell   1
# mongol   1
# nostradamus   1
# stepnicka   1
# vallone   1
# prison escape   1

# %% [markdown]
# Любовь, друг, убийство, смерть, полиция. Кто бы сомневался) <br>
# Делаем нормализацию перед тем как выводить данные на график.

# %%
plot_keywords_count = sum(drama_films_plot_keywords_counter.values())
for word, count in drama_films_plot_keywords_counter.items():
    drama_films_plot_keywords_counter[word] = (count /  plot_keywords_count) * 100

# %% [markdown]
# Рисуем наш график, чтобы визуально увидеть, какой общий сюжет преобладает у фильмов в жанре драма.

# %%
top_films_plot_keywords = dict(drama_films_plot_keywords_counter.most_common(10))
plt.figure(figsize=(18, 9))
plt.bar(list(top_films_plot_keywords.keys()), list(top_films_plot_keywords.values()), color='red')  
plt.xlabel('Слово') 
plt.ylabel('Процент') 
plt.title('Топ сюжетных слов в драматических фильмах', color='black') 
plt.savefig('Топ сюжетных слов в драматических фильмах.png')
plt.show()

# %% [markdown]
# **Анализ графика:** не могу сказать, что есть прямо какой-то общий сюжетный ход среди фильмов в жанре драма, ведь самое популярное слово, любовь, имеет лишь один процент популярности среди сюжетов. Но можно сказать, что сюжеты драматических фильмов довольно часто используют любовь и дружбу, убийства и смерти, полицию и школу. В целом, довольные обычные житейские вещи, кто ожидал здесь увидеть другое. Это же драматические фильмы.

# %% [markdown]
# ### Влияет ли возрастной рейтинг на бюджет фильма

# %% [markdown]
# Я человек простой, чтобы понять, влияет ли возрастной рейтинг на бюджет, сравню средний бюджет фильмов по возрастным рейтингам. А так же найду максимальные бюджеты среди каждого возрастного рейтинга.

# %%
content_rating_budget = Counter()
content_rating_films_count = Counter()
for index, row in df[['content_rating', 'budget']].iterrows():
    content_rating = row['content_rating']
    if content_rating != -1: 
        add_or_sum_to_counter(content_rating_budget, content_rating, row['budget'])
        add_or_sum_to_counter(content_rating_films_count, content_rating, 1)
print('Суммарный бюджет фильмов по возрастному ограничению:\n', prettify(content_rating_budget))
print('Количество фильмов по возрастному ограничению:\n', prettify(content_rating_films_count))
# Out:
# Суммарный бюджет фильмов по возрастному ограничению:
#  {
#     "PG-13": 74968648830.0,
#     "PG": 31840328920.0,
#     "G": 4814907000.0,
#     "R": 65862542481.0,
#     "TV-14": 18200000.0,
#     "TV-G": 18350000.0,
#     "Not Rated": 398649940.0,
#     "Unrated": 249555595.0,
#     "Approved": 207123765.0,
#     "NC-17": 55585000.0,
#     "X": 43400000.0,
#     "TV-MA": 34000000.0,
#     "GP": 22200000.0,
#     "Passed": 27282785.0,
#     "M": 18800000.0,
#     "TV-PG": 9600000.0
# }
# Количество фильмов по возрастному ограничению:
#  {
#     "PG-13": 1460,
#     "PG": 701,
#     "G": 112,
#     "R": 2118,
#     "TV-14": 30,
#     "TV-PG": 13,
#     "TV-MA": 20,
#     "TV-G": 10,
#     "Not Rated": 116,
#     "Unrated": 62,
#     "Approved": 55,
#     "TV-Y": 1,
#     "NC-17": 7,
#     "X": 13,
#     "TV-Y7": 1,
#     "GP": 6,
#     "Passed": 9,
#     "M": 5
# }

# %% [markdown]
# Получили наши данные: суммарный бюджет фильмов по возрастному ограничению, а так же количество фильмов по возрастному ограничению.<br>
# Странно, на последнем месте у нас один фильм из возрастной категории USA. Не уверен, что такая категория существует.
# А теперь находим среднее значение бюджета по возрастному ограничению для фильмов.

# %%
for content_rating in content_rating_budget.keys():
    take_avg(content_rating_budget, content_rating, content_rating_films_count[content_rating])
print('Средний бюджет фильмов по возрастному рейтингу: \n', prettify(content_rating_budget))
# Out:
# Средний бюджет фильмов по возрастному рейтингу:
#  {
#     "PG-13": 51348389.60958904,
#     "PG": 45421296.60485022,
#     "G": 42990241.071428575,
#     "R": 31096573.409348443,
#     "TV-14": 606666.6666666666,
#     "TV-G": 1835000.0,
#     "Not Rated": 3436637.4137931033,
#     "Unrated": 4025090.2419354836,
#     "Approved": 3765886.6363636362,
#     "NC-17": 7940714.285714285,
#     "X": 3338461.5384615385,
#     "TV-MA": 1700000.0,
#     "GP": 3700000.0,
#     "Passed": 3031420.5555555555,
#     "M": 3760000.0,
#     "TV-PG": 738461.5384615385
# }

# %% [markdown]
# Нашли средние рейтинги бюджетов по возрастным ограничениям. давайте строить наш график.

# %%
content_rating_budget_dict = dict(content_rating_budget.most_common())
plt.figure(figsize=(18, 9))
plt.bar(list(content_rating_budget_dict.keys()), list(content_rating_budget_dict.values()), color='purple')  
plt.xlabel('Возрастное ограничение') 
plt.ylabel('Средний бюджет фильма') 
plt.title('Влияние возрастного рейтинга на бюджет фильма', color='black') 
plt.savefig('Влияние возрастного рейтинга на бюджет фильма.png')
plt.show()

# %% [markdown]
# **Анализ графика:** мы видим, что первое место по среднему размеру бюджета заняли фильмы PG-13 (Просмотр не желателен детям до 13 лет). В целом, 5 первых мест по среднему бюджету фильма это фильмы, возрастное ограничение которых измеряется по [Системе рейтингов Американской киноассоциации](https://ru.wikipedia.org/wiki/%D0%A1%D0%B8%D1%81%D1%82%D0%B5%D0%BC%D0%B0_%D1%80%D0%B5%D0%B9%D1%82%D0%B8%D0%BD%D0%B3%D0%BE%D0%B2_%D0%90%D0%BC%D0%B5%D1%80%D0%B8%D0%BA%D0%B0%D0%BD%D1%81%D0%BA%D0%BE%D0%B9_%D0%BA%D0%B8%D0%BD%D0%BE%D0%B0%D1%81%D1%81%D0%BE%D1%86%D0%B8%D0%B0%D1%86%D0%B8%D0%B8).<br>
# Топ-3 по среднему бюджету это фильмы, которые можно смотреть детям до 13 лет (при PG-13 в сопровождении родителей). Основную закономерность я вижу в том, что фильмы, которые рекомендованы людям от 17 лет и выше, имеют значительно меньший бюджет, нежели фильмы, которые можно смотреть до 17 лет. Это можно легко объяснить тем, что чем ниже возрастной порог, тем больше людей посмотрит фильм, плюс, мультики и разные детские фильмы зачастую имеют огромный успех в прокате, потому их бюджет такой раздутый, ведь он окупается.<br>
# **Ответ на поставленный вопрос:** да, возрастной рейтинг фильма влияет на его бюджет, чем ниже возрастной рейтинг фильма, тем выше его средний бюджет. PG-13 вышел на первое место потому, что в нашем датасете много мировых хитов, которые, в основном, и сделаны PG-13 рейтингом. Фильмы для 17+ обладают в разы меньшим бюджетом, нежели фильмы разрешённые до 17.

# %% [markdown]
# И давайте ещё взглянем на наибольшие бюджеты среди каждой категории.

# %%
content_ratings = list(content_rating_budget_dict.keys())
biggest_budgets_by_content_rating = Counter()
for content_rating in content_ratings:
    biggest_budgets_by_content_rating[content_rating] = df[df['content_rating'] == content_rating]['budget'].max()
    
print('Рейтинг максимальных бюджетов фильмов по категориям:\n', prettify(biggest_budgets_by_content_rating.most_common()))
# Out:
# Рейтинг максимальных бюджетов фильмов по категориям:
#  [
#     [
#         "R",
#         12215500000.0
#     ],
#     [
#         "PG-13",
#         2400000000.0
#     ],
#     [
#         "PG",
#         1000000000.0
#     ],
#     [
#         "G",
#         200000000.0
#     ],
#     [
#         "Unrated",
#         103000000.0
#     ],
#     [
#         "NC-17",
#         45000000.0
#     ],
#     [
#         "Not Rated",
#         45000000.0
#     ],
#     [
#         "TV-MA",
#         34000000.0
#     ],
#     [
#         "Approved",
#         31115000.0
#     ],
#     [
#         "GP",
#         12000000.0
#     ],
#     [
#         "TV-14",
#         12000000.0
#     ],
#     [
#         "X",
#         8000000.0
#     ],
#     [
#         "Passed",
#         7623000.0
#     ],
#     [
#         "M",
#         7000000.0
#     ],
#     [
#         "TV-G",
#         7000000.0
#     ],
#     [
#         "TV-PG",
#         5000000.0
#     ]
# ]

# %% [markdown]
# Если проанализировать, то очень сильно бросается в глаза бюджет 12 215 500 000, надо бы проверить, что там за фильм та такой дорогой. И следующие два за ним тоже что-то сильно много денег имеют в бюджете.<br>
# Погуглив, я понял, что в наших данных бюджеты фильмов указаны в разной валюте. Кто-то в долларах, а кто-то в JPY. Значит не пасхалочка.<br>
# Получается, если у нас разные валюты указаны, но не указано нигде, какая валюта используется, то все наши графики описывающие деньги являются неточными. Надеюсь, так не было задумано.

# %% [markdown]
# ### Самое интересное - я целенаправленно внес некоторые некорректные данные (несуществующий фильм или фильмы или фичи) - надо его (их) найти.

# %% [markdown]
# Переходим к поиску пасхалок. Напомню списочек странностей, которые я уже замечал, пока делал другие пункты в этой части лабораторной работы:
# 1. фильмы биографические фильмы в топе по лайкам, рейтингу и прибыли;
# 2. неизвестный Google поиску режиссёр Aina Obama в парах с тремя фейковыми актёрами выбилась в топ по деньгам в прокате;
# 3. аномальный средний рейтинг в 98 баллов у фильмов из страны English;
# 4. значение "New Line" в качестве страны у фильма;
# 5. фильм, у которого возрастная категория была USA.
#
# Вроде как всё, что я заметил из странного. Приступаем. Начну с простого, глянем, что же это за фильм из страны English с рейтингом в 98 баллов.

# %%
print(df[df['country'] == 'English'][['movie_title', 'movie_imdb_link', 'imdb_score']])
# Out:
# Empty DataFrame
# Columns: [movie_title, movie_imdb_link, imdb_score]
# Index: []

# %% [markdown]
# И мы видим, что тут совсем какая-то беда с данными для этого фильма. Словно кто-то сдвинул их влево или вправо. Потому значения колонок не соответствуют своим колонками. Удалим отсюда этот фильм.

# %%
df = df.drop(df[df['country'] == 'English'].index)
print(len(df))
# Out:
# 5046

# %% [markdown]
# Отлично, переходим к фильму с режиссёром Aina Obama.

# %%
print(df[df['director_name'] == 'Aina Obama']
      [['movie_title', 'movie_imdb_link', 'director_name', 'actor_1_name', 'actor_2_name', 'actor_3_name']])
# Out:
# Empty DataFrame
# Columns: [movie_title, movie_imdb_link, director_name, actor_1_name, actor_2_name, actor_3_name]
# Index: []

# %% [markdown]
# Актёры и имя у фильма странные. Переходим по линке на imdb и видим, что фильм то вовсе и не тот. Режисёр и актёры другие. Имена разве что похожие, из оригинального Aroused  кто-то убрал все согласные и вставил ! вместо них. Фильм то какой подобрали, ставлю лайк, но из наших данных всё таки его уберу.

# %%
df = df.drop(df[df['director_name'] == 'Aina Obama'].index)
print(len(df))
# Out:
# 5046

# %% [markdown]
# Итого мы нашли две из пяти пасхалок. Идём дальше. Посмотрим, что там за "New Line" в качестве страны у фильма.<br>
# Я подсмотрел в интернете, есть библиотечка одна, которая страны хранит. Добавлю её, чтобы не набирать руками.<br>
# Вам, возможно, она пригодиться для запуска моего ноутбука. Вот так её можно установить `pip install pycountry`.<br>
# К сожалению, не все страны учтены в библиотеке, потому добавим руками те, каких не хватает. И не забудем о -1.

# %%
import pycountry

countries_names = [country.name for country in list(pycountry.countries)]
countries_names.extend(["USA", "UK", -1, "Czech Republic", "Soviet Union", "South Korea", "Russia", "West Germany", "Taiwan", "Iran"])
print(df[~df['country'].isin(countries_names)][['movie_title', 'movie_imdb_link', 'country']])
# Out:
# Empty DataFrame
# Columns: [movie_title, movie_imdb_link, country]
# Index: []

# %% [markdown]
# Мы видим, что есть два фильма, у которых некорректная страна указана. Удаляем записи с ними.

# %%
df = df.drop(df[~df['country'].isin(countries_names)].index)
print(len(df))
# Out:
# 5046

# %% [markdown]
# Нашли ещё две испорченных записи с фильмами. Осталась одна.<br>
# Посмотрим, что там в фильмах с жанром биография.

# %%
biography_films = df[df['genres'].str.contains('Biography')]
print(biography_films[biography_films['movie_facebook_likes'] == biography_films['movie_facebook_likes'].max()]
      [['movie_title', 'movie_imdb_link']])
print(biography_films[biography_films['gross'] == biography_films['gross'].max()]
      [['movie_title', 'movie_imdb_link']])
print(biography_films[biography_films['imdb_score'] == biography_films['imdb_score'].max()]
      [['movie_title', 'movie_imdb_link']])
# Out:
#               movie_title                                    movie_imdb_link
# 2615  The Imitation Game   http://www.imdb.com/title/tt2084970/?ref_=fn_t...
#           movie_title                                    movie_imdb_link
# 814  American Sniper   http://www.imdb.com/title/tt2179136/?ref_=fn_t...
#             movie_title                                    movie_imdb_link
# 1875  Schindler's List   http://www.imdb.com/title/tt0108052/?ref_=fn_t...

# %% [markdown]
# нет, ошибочка вышла. Фильмы выглядят нормальными. Посмотрим, что там за фильм был с категорией USA.

# %%
print(df[df['content_rating'] == 'USA'][['movie_title', 'movie_imdb_link', 'content_rating']])
# Out:
# Empty DataFrame
# Columns: [movie_title, movie_imdb_link, content_rating]
# Index: []

# %% [markdown]
# Пусто. Мы уже удалили этот фильм.

# %% [markdown]
# Сохраним наши очищенные данные в новый файлик.

# %%
df.to_csv('filtered_cinema1.csv')

# %% [markdown]
# Запустим наш код заново, но уже используя `filtered_cinema1.csv` и увидим, что графики теперь не содержат аномалий.
